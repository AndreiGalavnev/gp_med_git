# %%
import datetime as dt
from typing import List, Optional
import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup
import time
from abc import ABC, abstractmethod

# %%
class Analisys:
    
    def __init__(self, source: str, chapter: str|None, analisys_name: str, analisys_cost:str, analisys_comment: str,):              

        self.source    = source
        self.chapter     = chapter
        self.analisys_name   = analisys_name
        self.analisys_cost   = analisys_cost
        self.analisys_comment  = analisys_comment

    def __repr__(self) -> str:
        return f"source = {self.source}, chapter = {self.chapter}, analisys_name = {self.analisys_name}, analisys_cost = {self.analisys_cost}, analisys_comment = {self.analisys_comment}"
    
    def to_dict(self) -> dict:
        return self.__dict__


#     def to_DB(self, ...):
#         ...

#     @classmethod
#     def from_DB(cls, ...):
#         ...

# %% [markdown]
# This code defines a class named Analisys that represents an analysis with several attributes: source, chapter, analisys_name, analisys_cost, and analisys_comment. The class has an __init__ method that takes these attributes as arguments and initializes the corresponding instance variables. The class also has a __repr__ method that returns a string representation of the object, and a to_dict method that returns a dictionary representation of the object.
#
# The __init__ method takes five arguments: source, chapter, analisys_name, analisys_cost, and analisys_comment. The chapter argument is annotated with the type hint str|None, which means that it can be either a string or None. The other arguments are annotated with the type hint str, which means that they should be strings.
#
# The __repr__ method returns a string representation of the object in the format "source = {self.source}, chapter = {self.chapter}, analisys_name = {self.analisys_name}, analisys_cost = {self.analisys_cost}, analisys_comment = {self.analisys_comment}".
#
# The to_dict method returns a dictionary representation of the object by calling the __dict__ method on the instance, which returns a dictionary containing the instance’s attributes.

# %%
class WebDriver(ABC):

    def __init__(self):
        self.urls: List[str] = []
            
    def _scan_page(self, url:str):
        # Прописываем нестандартный заголовок, чтобы сайт не принял нас за бота, который парсит его данные :)
        headers = requests.utils.default_headers()
        headers.update({
                    "accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9",
                    "user-agent": 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/101.0.4951.67 Safari/537.36',
            })

        response = requests.get(url=url, headers=headers)

        if not response.ok:
            raise ValueError("no content to parse")

        return BeautifulSoup(response.content.decode(), "lxml")            

    @abstractmethod
    def get_analisys(self) :  
        ...

# %% [markdown]
# {'source': "medart.by/",
#   'chapter': 'Лаборатория, Анализ крови',
#   'analisys_name': 'Общий анализ крови из вены',
#   'analisys_cost': '24.17 руб.',
#   'analisys_comment': 'https://medart.by/price'+'/services/analiz-krovi/obshchiy-analiz-krovi-iz-veny/'},

# %%
class DriverMakayonka(WebDriver):
    
    URL = "https://makaenka17med.by/prices/"
    NAME = "makaenka17med.by"

    def __init__(self):
        ...
        
    def get_analisys(self) :
        analisys_dict={}
        i=0
        soup = self._scan_page(self.URL)
        for tag in soup.find_all(name="div", class_ = "dropdown-item"):
            analisys_comment = ""
            chapter = tag.find(name="button").text

            for row in tag.find(name="tbody").find_all("tr"):
                if row.find(name="div", class_="table-list__title"):
                    analisys_comment = row.find(name="div", class_="table-list__title").text
                else: 
                    columns = row.find_all("td")

                    analisys_name = columns[0].text
                    analisys_cost = columns[1].text
                    analisys = Analisys(self.NAME, chapter, analisys_name, analisys_cost, analisys_comment)
                    analisys_dict[i] = (analisys.to_dict())
                    i += 1

        return analisys_dict

# %%
class DriverMedart(WebDriver):
    
    URL = "https://medart.by/price/"
    NAME = "medart.by/"

    def get_analisys(self) :
        
        analisys_dict={}
        i=0
        soup = self._scan_page(self.URL)

        ID = ["sect_6", "sect_5", "sect_7", "sect_8", "sect_9", "sect_10", "sect_11", "sect_12", "sect_13", "sect_14", "sect_15", "sect_16", "sect_17", "sect_19", "sect_146", "sect_151"]
        
        for k in ID:
            tag = soup.find('div', class_='section_filter', id=f"{k}")

            R = tag.find(class_= 'pricemain-title_left sticky').text.strip()
            V = tag.find(class_= 'title').text.strip()
            S = tag.find(class_='categoriesmain_price-table').find('table')
#             print(R,V)

            # Находим все строки таблицы, кроме первой (заголовочной)
            rows = S.find_all("tr")#[1:]
            for row in rows:
#                 Проверяем, есть ли у элемента row атрибут colspan
                if row.find("td").has_attr('colspan'):
                    V = row.find("td", class_="title").text
                    continue
    
#                 Иначе продолжаем как обычно
                
                name_elem = row.find("td", class_="name")
                if name_elem is None:
                    print("Элемент name не найден!")
                    continue
                name = name_elem.get_text(strip=True)
                print(R,V,name)

                link = row.find("td", class_="name").find('a').get('href')
                                
                price_elem = row.find("td", class_="price")
                if price_elem is None:
                    print("Элемент price не найден!")
                    continue
                price = price_elem.get_text(strip=True)
                                
                chapter = (R,V)
                analisys_name = name
                analisys_cost = price
                analisys_comment = "https://medart.by"+link
                analisys = Analisys(self.NAME, chapter, analisys_name, analisys_cost, analisys_comment)
                analisys_dict[i] = (analisys.to_dict())
                i+=1 
                print('I=',i)
                print(analisys_dict)

        return analisys_dict

m = DriverMedart()
m.get_analisys()
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 62
#      59         return analisys_dict
#      61 m = DriverMedart()
# ---> 62 m.get_analisys()
#
# Cell In[11], line 19, in DriverMedart.get_analisys(self)
#      15 tag = soup.find('div', class_='section_filter', id=f"{k}")
#      16 # print(k)
#      17 # print(type(tag),len(tag),tag[0])
# ---> 19 R = tag.find(class_= 'pricemain-title_left sticky').text.strip()
#      20 V = tag.find(class_= 'title').text.strip()
#      21 S = tag.find(class_='categoriesmain_price-table').find('table')
#
# AttributeError: 'NoneType' object has no attribute 'find'

# %%
df_med_art = pd.DataFrame.from_dict(m.get_analisys().values())
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
df_med_art.tail(40)
# Out:
#          source             chapter  \
# 225  medart.by/    (Стоматология, )
# 226  medart.by/    (Стоматология, )
# 227  medart.by/    (Стоматология, )
# 228  medart.by/    (Стоматология, )
# 229  medart.by/    (Стоматология, )
# 230  medart.by/    (Стоматология, )
# 231  medart.by/    (Стоматология, )
# 232  medart.by/    (Стоматология, )
# 233  medart.by/    (Стоматология, )
# 234  medart.by/    (Стоматология, )
# 235  medart.by/            (ТАПБ, )
# 236  medart.by/            (ТАПБ, )
# 237  medart.by/        (Хирургия, )
# 238  medart.by/        (Хирургия, )
# 239  medart.by/        (Хирургия, )
# 240  medart.by/        (Хирургия, )
# 241  medart.by/        (Хирургия, )
# 242  medart.by/        (Хирургия, )
# 243  medart.by/        (Хирургия, )
# 244  medart.by/        (Хирургия, )
# 245  medart.by/        (Хирургия, )
# 246  medart.by/       (Педиатрия, )
# 247  medart.by/       (Педиатрия, )
# 248  medart.by/       (Педиатрия, )
# 249  medart.by/       (Педиатрия, )
# 250  medart.by/       (Педиатрия, )
# 251  medart.by/       (Педиатрия, )
# 252  medart.by/       (Педиатрия, )
# 253  medart.by/       (Педиатрия, )
# 254  medart.by/       (Педиатрия, )
# 255  medart.by/       (Педиатрия, )
# 256  medart.by/       (Педиатрия, )
# 257  medart.by/       (Педиатрия, )
# 258  medart.by/       (Педиатрия, )
# 259  medart.by/       (Педиатрия, )
# 260  medart.by/       (Педиатрия, )
# 261  medart.by/       (Педиатрия, )
# 262  medart.by/       (Онкология, )
# 263  medart.by/       (Онкология, )
# 264  medart.by/  (Трепан-биопсия, )
#
#                                          analisys_name  \
# 225        Ультразвуковая чистка зубов (цена за 1 зуб)
# 226                                 Композитные виниры
# 227               Лечение корневых каналов (цена за 1)
# 228                                Лечение пародонтоза
# 229                                Лечение пародонтита
# 230                                   Лечение пульпита
# 231                                    Лечение кариеса
# 232                                   Установка пломбы
# 233                                   Временная пломба
# 234                             Стекловолоконный штифт
# 235              Пункционная биопсия щитовидной железы
# 236                Пункционная биопсия молочной железы
# 237                            Удаление дерматофибромы
# 238             Первичная хирургическая обработка раны
# 239                                    Удаление липомы
# 240                                   Удаление атеромы
# 241                                 Удаление бородавок
# 242                                   Удаление невусов
# 243                                  Удаление папиллом
# 244                                          Перевязка
# 245                                          Анестезия
# 246  Консультация врача-педиатра первой или высшей ...
# 247  Повторная консультация врача-педиатра первой и...
# 248                             Лечение головных болей
# 249                         Лечение слабости у ребенка
# 250                      Лечение ротавирусной инфекции
# 251                          Лечение кишечной инфекции
# 252                     Лечение интоксикации у ребенка
# 253                             Лечение диареи у детей
# 254                  Лечение воспаления легких у детей
# 255                          Лечение вирусной инфекции
# 256                    Лечение боли в суставах у детей
# 257                              Лечение боли в животе
# 258                               Лечение сыпи у детей
# 259                                   Лечение бронхита
# 260                                      Лечение кашля
# 261                            Лечение простуды и ОРВИ
# 262  Консультация врача-онколога первой или высшей ...
# 263  Повторная консультация врача-онколога первой и...
# 264                     Трепан биопсия молочной железы
#
#                  analisys_cost  \
# 225                   5.29руб.
# 226  Уточняйте по телефонуруб.
# 227                  48.75руб.
# 228  Уточняйте по телефонуруб.
# 229  Уточняйте по телефонуруб.
# 230  Уточняйте по телефонуруб.
# 231  Уточняйте по телефонуруб.
# 232  Уточняйте по телефонуруб.
# 233                   6.20руб.
# 234                  20.04руб.
# 235              от 109,29руб.
# 236              от 109,29руб.
# 237  Уточняйте по телефонуруб.
# 238                  37.50руб.
# 239  Уточняйте по телефонуруб.
# 240  Уточняйте по телефонуруб.
# 241  Уточняйте по телефонуруб.
# 242  Уточняйте по телефонуруб.
# 243  Уточняйте по телефонуруб.
# 244                  18.19руб.
# 245                  27.22руб.
# 246                  47,08руб.
# 247                  38,25руб.
# 248  Уточняйте по телефонуруб.
# 249  Уточняйте по телефонуруб.
# 250  Уточняйте по телефонуруб.
# 251  Уточняйте по телефонуруб.
# 252  Уточняйте по телефонуруб.
# 253  Уточняйте по телефонуруб.
# 254  Уточняйте по телефонуруб.
# 255  Уточняйте по телефонуруб.
# 256  Уточняйте по телефонуруб.
# 257  Уточняйте по телефонуруб.
# 258  Уточняйте по телефонуруб.
# 259  Уточняйте по телефонуруб.
# 260  Уточняйте по телефонуруб.
# 261  Уточняйте по телефонуруб.
# 262                  47,08руб.
# 263                  38,25руб.
# 264                 155.61руб.
#
#                                       analisys_comment
# 225  https://medart.by/services/stomatologiya/ultra...
# 226  https://medart.by/services/stomatologiya/kompo...
# 227  https://medart.by/services/stomatologiya/leche...
# 228  https://medart.by/services/stomatologiya/leche...
# 229  https://medart.by/services/stomatologiya/leche...
# 230  https://medart.by/services/stomatologiya/leche...
# 231  https://medart.by/services/stomatologiya/leche...
# 232  https://medart.by/services/stomatologiya/ustan...
# 233  https://medart.by/services/stomatologiya/vreme...
# 234  https://medart.by/services/stomatologiya/stekl...
# 235  https://medart.by/services/tapb/punktsionnaya-...
# 236  https://medart.by/services/tapb/punktsionnaya-...
# 237  https://medart.by/services/khirurgiya/udalenie...
# 238  https://medart.by/services/khirurgiya/pervichn...
# 239  https://medart.by/services/khirurgiya/udalenie...
# 240  https://medart.by/services/khirurgiya/udalenie...
# 241  https://medart.by/services/khirurgiya/udalenie...
# 242  https://medart.by/services/khirurgiya/udalenie...
# 243  https://medart.by/services/khirurgiya/udalenie...
# 244  https://medart.by/services/khirurgiya/perevyazka/
# 245  https://medart.by/services/khirurgiya/anesteziya/
# 246  https://medart.by/services/pediatriya/konsulta...
# 247  https://medart.by/services/pediatriya/povtorna...
# 248  https://medart.by/services/pediatriya/lechenie...
# 249  https://medart.by/services/pediatriya/lechenie...
# 250  https://medart.by/services/pediatriya/lechenie...
# 251  https://medart.by/services/pediatriya/lechenie...
# 252  https://medart.by/services/pediatriya/lechenie...
# 253  https://medart.by/services/pediatriya/lechenie...
# 254  https://medart.by/services/pediatriya/lechenie...
# 255  https://medart.by/services/pediatriya/lechenie...
# 256  https://medart.by/services/pediatriya/lechenie...
# 257  https://medart.by/services/pediatriya/lechenie...
# 258  https://medart.by/services/pediatriya/lechenie...
# 259  https://medart.by/services/pediatriya/lechenie...
# 260  https://medart.by/services/pediatriya/lechenie...
# 261  https://medart.by/services/pediatriya/lechenie...
# 262  https://medart.by/services/onkologiya/konsulta...
# 263  https://medart.by/services/onkologiya/povtorna...
# 264  https://medart.by/services/trepan-biopsiya/tre...

# %% [markdown]
# {0: {'source': 'makaenka17med.by',
#   'chapter': 'КОНСУЛЬТАЦИИ СПЕЦИАЛИСТОВ \n\n\n',
#   'analisys_name': 'Консультация врача-специалиста второй категории, без ктегории терапевтического профиля',
#   'analisys_cost': '30,33 BYN',
#   'analisys_comment': 'Консультация первичная:'
# <!-- class DriverMakayonka(WebDriver):
#
#     URL = "https://makaenka17med.by/prices/"
#     NAME = "makaenka17med.by"
#
#     def __init__(self):
#         ...
#
#     def get_analisys(self) :
#         analisys_dict={}
#         i=0
#         soup = self._scan_page(self.URL)
#         for tag in soup.find_all(name="div", class_ = "dropdown-item"):
#             analisys_comment = ""
#             chapter = tag.find(name="button").text
#
#             for row in tag.find(name="tbody").find_all("tr"):
#                 if row.find(name="div", class_="table-list__title"):
#                     analisys_comment = row.find(name="div", class_="table-list__title").text
#                 else:
#                     columns = row.find_all("td")
#
#                     analisys_name = columns[0].text
#                     analisys_cost = columns[1].text
#                     analisys = Analisys(self.NAME, chapter, analisys_name, analisys_cost, analisys_comment)
#                     analisys_dict[i] = (analisys.to_dict())
#                     i += 1
#
#         return analisys_dict -->

# %% [markdown]
# This code defines a class called WebDriver that inherits from the ABC (Abstract Base Class) class. The WebDriver class has an __init__ method that initializes an instance variable called urls as an empty list.
#
# The class also defines a method called _scan_page that takes a URL as an argument. This method sets up some headers for a web request, including a custom user-agent, and then uses the requests library to send a GET request to the specified URL with these headers.
#
# If the response to this request is not successful (i.e., if the ok attribute of the response object is False), then the method raises a ValueError with the message “no content to parse”. Otherwise, it uses the BeautifulSoup library to parse the content of the response, which is first decoded, and returns the resulting BeautifulSoup object.
#
# The class also defines an abstract method called get_analisys, which means that any concrete subclass of WebDriver must implement this method. The implementation of this method is not shown in the code you provided.
#
# In summary, this code defines a class that can be used to send a GET request to a specific URL, parse the response using BeautifulSoup, and provides an abstract method for performing some kind of analysis on the data.

# %%
class DriverSynlab(WebDriver):
    
    URL = "https://www.synlab.by"
    NAME = "Synlab.by"

    def __init__(self):
        
        super().__init__()
#         self.urls : List[str] = []
        self._chapters : List[str] = []

    def scan(self):
        url = "https://www.synlab.by/ru/%D0%BF%D1%80%D0%B5%D0%B9%D1%81%D0%BA%D1%83%D1%80%D0%B0%D0%BD%D1%82"
        soup = self._scan_page(url=url)
        tag = soup.find(name="ul", class_ = "nav menu checkup-menu mod-list")
    
        for a in tag.find_all("a"):

            url_chapter = DriverSynlab.URL + a.get("href")
            chapter = a.text
            self.urls = np.append(self.urls, url_chapter)
            self._chapters = np.append(self._chapters , chapter)
            # print(f"{url_capter = }, {name_capter = }")

        return(self)


    def get_analisys(self) :
        i = 0
#         analisys_list = []
        analisys_dict = {}

        for url_chapter, chapter in zip(self.urls, self._chapters):
            soup = self._scan_page(url_chapter)
            for tag in soup.find_all("table"):

                if tag: 
                    
                    for tr in tag.find_all("tr"):

                        t_columns = tr.find_all("td")
                        analisys_name = t_columns[0].text
                        analisys_cost = t_columns[1].text
                        if len(t_columns) == 3:
                            analisys_comment = t_columns[2].text

                        analisys = Analisys(DriverSynlab.NAME, chapter, analisys_name, analisys_cost, analisys_comment)
                        analisys_dict[i] = (analisys.to_dict())
#                         analisys_list.append(analisys)
                
                        i+=1

            time.sleep(2) # ставим задержку 2 секунды после парсинга каждого раздела
        return analisys_dict

# %%
d=DriverSynlab()
a=d.scan()
print(a)
# Out:
# <__main__.DriverSynlab object at 0x000001AF6B7A8890>

# %% [markdown]
# This code defines a class called DriverSynlab that inherits from the WebDriver class. The DriverSynlab class has two class variables, URL and NAME, which are set to the string values "https://www.synlab.by" and "Synlab.by", respectively.
#
# The class also has an __init__ method that calls the __init__ method of its superclass (WebDriver) using the super() function. It then initializes an instance variable called _chapters as an empty list.
#
# The class defines a method called scan that takes no arguments. This method sets a local variable called url to a specific URL, and then calls the _scan_page method of its superclass with this URL as an argument. The result of this call, which should be a BeautifulSoup object, is stored in a local variable called soup.
#
# Next, the method uses the find method of the soup object to find the first ul element on the page that has a class attribute equal to "nav menu checkup-menu mod-list". This element is stored in a local variable called tag.
#
# The method then enters a loop that iterates over all a elements within this tag element using the find_all method. For each of these elements, it constructs a new URL by concatenating the value of the class variable URL with the value of the href attribute of the current a element. This new URL is stored in a local variable called url_chapter.
#
# The method also extracts the text from the current a element and stores it in a local variable called chapter. It then appends both of these values to the instance variables urls and _chapters, respectively, using the np.append function from the NumPy library.
#
# After this loop completes, the method returns itself (i.e., the instance of the DriverSynlab class on which it was called).
#
# The class also defines a method called get_analisys, which overrides the abstract method with the same name in its superclass (WebDriver). This method initializes two local variables, i and analisys_dict, to 0 and an empty dictionary, respectively.
#
# It then enters a loop that iterates over pairs of values from the instance variables urls and _chapters. For each pair of values, it calls the _scan_page method of its superclass with the current value of url_chapter as an argument. The result of this call, which should be a BeautifulSoup object, is stored in a local variable called soup.
#
# Next, it enters another loop that iterates over all <table> elements on the page using the <EUGPSCoordinates> method of the <EUGPSCoordinates> object. If any such elements are found, it enters yet another loop that iterates over all <tr> elements within each <table> element using the <EUGPSCoordinates> method.
#
# For each <tr> element, it finds all <td> elements within it using another call to <EUGPSCoordinates>. It then extracts text from these elements and stores it in local variables called <EUGPSCoordinates>, <EUGPSCoordinates>, and (if there are three <td> elements) <EUGPSCoordinates>.
#
# Next, it creates an instance of a class called <EUGPSCoordinates> with these values as arguments (as well as some other values), and calls its <EUGPSCoordinates> method to convert it to a dictionary. This dictionary is then added to the <EUGPSCoordinates> dictionary with <EUGPSCoordinates> as its key.
#
# After this innermost loop completes, <EUGPSCoordinates> is incremented by 1 and a delay of 2 seconds is introduced using the <EUGPSCoordinates> function from Python’s built-in time module.
#
# After all loops complete, this method returns the value of <EUGPSCoordinates>.

# %%
class DriverKVD(WebDriver):
    
    URL = "https://kvd.by/%D0%BF%D0%BB%D0%B0%D1%82%D0%BD%D1%8B%D0%B5-%D1%83%D1%81%D0%BB%D1%83%D0%B3%D0%B8/%D0%BF%D1%80%D0%B5%D0%B9%D1%81%D0%BA%D1%83%D1%80%D0%B0%D0%BD%D1%82%D1%8B-%D0%B4%D0%BB%D1%8F-%D0%B3%D1%80%D0%B0%D0%B6%D0%B4%D0%B0%D0%BD-%D1%80%D0%B5%D1%81%D0%BF%D1%83%D0%B1%D0%BB%D0%B8%D0%BA%D0%B8-%D0%B1%D0%B5%D0%BB%D0%B0%D1%80%D1%83%D1%81%D1%8C"
    NAME = "kvd.by"

    def __init__(self):
        # Описываем все имеющиеся таблицы:
        # key - количество столбцов в таблице
        # value: 0 - номер столбца, содержащего название анализа
        # value: 1 - номер столбца, содержащего цену
        self.dict_tables = {
                10 : (2, 9),
                2 : (0, 1),
                7 : (1, 6),
                8 : (1, 7)
                }

    def get_analisys(self) :
        
        analisys_dict = {}
        soup = self._scan_page(self.URL)
        i = 0
        for tag in soup.find_all(name="div", class_ = "entry spoiler"):

#             date_update = tag.find("table").find_previous("p").strong.text
#             date_update = dt.datetime.strptime(date_update, "%d.%m.%Y")

            chapter = tag.find("h3").text

        #     n_td - количество столбцов в таблице, считаю по последней строке
            n_td = len(tag.find(class_="cool-table").find_all("tr")[-1].find_all("td"))
            for row in tag.find(class_="cool-table").find_all("tr"):
                if n_td == len(row.find_all("td")):
                    t_columns = row.find_all("td")
        #             n_td = len(t_columns)
                    analisys_name = t_columns[self.dict_tables[n_td][0]].text
                    analisys_cost = t_columns[self.dict_tables[n_td][1]].text
                    analisys = Analisys(self.NAME, chapter, analisys_name, analisys_cost, '')
                    analisys_dict[i] = (analisys.to_dict())
                    i += 1
                    
        return analisys_dict

# %% [markdown]
# This code defines a class `DriverMakayonka` that inherits from the `WebDriver` class. The `DriverMakayonka` class has two class attributes: `URL`, which is set to the string `"https://makaenka17med.by/prices/"`, and `NAME`, which is set to the string `"makaenka17med.by"`. The class also defines an instance method `get_analisys` that takes no arguments and returns a dictionary.
#
# The `get_analisys` method creates an empty dictionary `analisys_dict` and a counter variable `i` initialized to 0. It then calls the `_scan_page` method with the `URL` attribute as an argument and assigns the result to the variable `soup`. The method then iterates over all `div` elements with the class `"dropdown-item"` found in `soup`. For each such element, it extracts the text of a child `button` element and assigns it to the variable `chapter`. It then iterates over all `tr` elements found in a child `tbody` element. If a `tr` element contains a child `div` element with the class `"table-list__title"`, it extracts its text and assigns it to the variable `analisys_comment`. Otherwise, it extracts the text of two child `td` elements and assigns them to the variables `analisys_name` and `analisys_cost`, respectively. It then creates an instance of the `Analisys` class with arguments `self.NAME`, `chapter`, `analisys_name`, `analisys_cost`, and `analisys_comment`, calls its `to_dict` method, and adds the result to the dictionary `analisys_dict` with key `i`. Finally, it increments the counter variable `i`.
#
# After all iterations are complete, the method returns the dictionary `analisys_dict`.
#
# Is there anything else you would like me to explain? 😊

# %%
class DriverMakayonka(WebDriver):
    
    URL = "https://makaenka17med.by/prices/"
    NAME = "makaenka17med.by"

    def __init__(self):
        ...
        
    def get_analisys(self) :
        analisys_dict={}
        i=0
        soup = self._scan_page(self.URL)
        for tag in soup.find_all(name="div", class_ = "dropdown-item"):
            analisys_comment = ""
            chapter = tag.find(name="button").text

            for row in tag.find(name="tbody").find_all("tr"):
                print('row - for row in tag.find(name="tbody").find_all("tr"):----  ',row)
                if row.find(name="div", class_="table-list__title"):
                    analisys_comment = row.find(name="div", class_="table-list__title").text
                else: 
                    columns = row.find_all("td")

                    analisys_name = columns[0].text
                    analisys_cost = columns[1].text
                    analisys = Analisys(self.NAME, chapter, analisys_name, analisys_cost, analisys_comment)
                    analisys_dict[i] = (analisys.to_dict())
                    i += 1

        return analisys_dict

# %%
maka = DriverMakayonka()

# %%
dict_maka = maka.get_analisys()
dict_maka
# Out:
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td class="table-list__title-wrapper" colspan="3">
# <div class="table-list__title">Консультация первичная:</div>
# </td>
# </tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Консультация врача-специалиста второй категории, без ктегории терапевтического профиля</td><td>30,33 BYN</td><td>53,24 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Консультация врача-специалиста первой категории терапевтического профиля</td><td>31,13 BYN</td><td>54,59 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Консультация врача-специалиста высшей категории терапевтического профиля</td><td>32,24 BYN</td><td>55,97 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Консультация врача-специалиста КМН терапевтического профиля</td><td>48,24 BYN</td><td>63,08 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Консультация врача-специалиста ДМН терапевтического профиля</td><td>48,88 BYN</td><td>64,62 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Консультация доцента КМН терапевтического профиля</td><td>48,45 BYN</td><td>64,04 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Консультация профессора ДМН терапевтического профиля</td><td>50,60 BYN</td><td>67,10 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Консультация врача-специалиста второй категории, без категории хирургического профиля</td><td>31,68 BYN</td><td>54,25 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Консультация врача-специалиста первой кат.хирургического профиля</td><td>32,66 BYN</td><td>56,74 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Консультация врача-специалиста высшей  кат.хирургического профиля</td><td>33,92 BYN</td><td>57,42 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Консультация врача-специалиста КМН хирургического профиля</td><td>50,06 BYN</td><td>64,06 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Консультация врача-специалиста ДМН хирургического профиля</td><td>51,97 BYN</td><td>65,79 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Консультация доцента КМН хирургического профиля</td><td>52,24 BYN</td><td>65,06 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Консультация профессора доктора медицинских наук хирургического профиля</td><td>54,25 BYN</td><td>68,71 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Консультация врача акушера-гинеколога второй категории</td><td>32,86 BYN</td><td>55,43 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Консультация врача акушера-гинеколога первой категории</td><td>33,84 BYN</td><td>57,92 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Консультация врача акушера-гинеколога высшей категории</td><td>35,10 BYN</td><td>58,60 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Консультация врача акушера-гинеколога, КМН</td><td>51,24 BYN</td><td>65,24 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Консультация врача акушера-гинеколога, ДМН</td><td>53,15 BYN</td><td>66,97 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Консультация врача акушера-гинеколога, доцента, КМН</td><td>53,42 BYN</td><td>66,24 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Телеконсультация врача-специалиста on-line</td><td>15,50 BYN</td><td></td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Телеконсультация врача-специалиста off-line</td><td>15,50 BYN</td><td></td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td class="table-list__title-wrapper" colspan="3">
# <div class="table-list__title">КОНСУЛЬТАЦИЯ ПОВТОРНАЯ</div>
# </td>
# </tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Повторная консультация врача-специалиста второй квалификационной категории, без категории терапевтического профиля</td><td>21,38 BYN</td><td>37,42 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Повторная консультация врача-специалиста первой квалификационной категории терапевтического профиля</td><td>21,94 BYN</td><td>38,36 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Повторная консультация врача-специалиста высшей квалификационной категории терапевтического профиля</td><td>22,72 BYN</td><td>39,33 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Повторная консультация врача-специалиста кандидата медицинских наук терапевтического профиля</td><td>33,92 BYN</td><td>44,30 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Повторная консультация врача-специалиста доктора медицинских наук терапевтического профиля</td><td>34,36 BYN</td><td>45,38 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Повторная консультация доцента кандидата медицинских наук терапевтического профиля</td><td>34,06 BYN</td><td>44,98 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Повторная консультация профессора ДМН терапевтического профиля</td><td>35,57 BYN</td><td>47,12 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Повторная консультация врача-специалиста второй квалификационной категории, без ктегории хирургического профиля</td><td>22,38 BYN</td><td>38,18 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Повторная консультация врача-специалиста первой квалификационной категории хирургического профиля</td><td>23,06 BYN</td><td>39,92 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Повторная консультация врача-специалиста высшей квалификационной категории хирургического профиля</td><td>23,95 BYN</td><td>40,40 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Повторная консультация врача-специалиста кандидата медицинских наук хирургического профиля</td><td>35,24 BYN</td><td>45,04 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Повторная консультация врача-специалиста доктора медицинских наук хирургического профиля</td><td>36,58 BYN</td><td>46,25 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Повторная консультация доцента кандидата медицинских наук хирургического профиля</td><td>36,77 BYN</td><td>45,74 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Повторная консультация профессора ДМН хирургического профиля</td><td>38,18 BYN</td><td>48,30 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Повторная консультация врача-акушер-гинеколога второй квалификационной категории </td><td>23,56 BYN</td><td>39,36 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Повторная консультация врача-акушер-гинеколога первой квалификационной категории </td><td>24,24 BYN</td><td>41,10 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Повторная консультация врача-акушер-гинеколога высшей  квалификационной категории </td><td>25,13 BYN</td><td>41,58 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Повторная консультация врача-акушер-гинеколога кандидата медицинских наук </td><td>36,42 BYN</td><td>46,22 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Повторная консультация врача-акушер-гинеколога доктора медицинских наук </td><td>37,76 BYN</td><td>47,43 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Повторная консультация врача акушера-гинеколога, доцента, КМН</td><td>37,95 BYN</td><td>46,92 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Консультация мультидисциплинарной бригады (МДБ) (акция до 31.08.2023)</td><td>140,00 BYN</td><td>140,00 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Повторная консультация мультидисциплинарной бригады (МДБ)</td><td>140,00 BYN</td><td>140,00 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Массаж с элементами мануальной терапии ( в том числе разработки контрактур)</td><td>60,00 BYN</td><td>60,00 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Забор мазка на исследование </td><td>4,62 BYN</td><td>8,87 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Каждый последующий забор мазка на исследование </td><td>2,73 BYN</td><td>6,98 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Забор цервикальной жидкости</td><td>7,46 BYN</td><td>15,83 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Кольпоцитология</td><td></td><td>8,60 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Стереоскопическая видеокольпоскопия нижнего отдела полового тракта (простая и расширенная)</td><td>54,56 BYN</td><td>80,02 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Кольпоскопия расширенная с цитологией</td><td>20,39 BYN</td><td>40,07 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Стереоскопическая видеокольпоскопия  нижнего отдела полового тракта расширенная с цитологией</td><td>54,91 BYN</td><td>80,37 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Кольпоскопия расширенная</td><td>18,25 BYN</td><td>30,45 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Лечебная процедура (1 ванночка)</td><td>5,74 BYN</td><td>11,69 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Лечебная процедура (введение лечебных тампонов)</td><td>5,77 BYN</td><td>11,72 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Медикаментозный аборт</td><td>272,48 BYN</td><td>290,43 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Диатермоэлектрокоагуляция</td><td></td><td>45,87 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Электроконизация шейки матки</td><td></td><td>56,22 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Введение внутриматочного средства для контрацепции</td><td>15,25 BYN</td><td>29,87 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Удаление внутриматочного средства для контрацепции</td><td>16,65 BYN</td><td>29,80 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Аспирационная биопсия из полости матки</td><td></td><td>32,43 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Биопсия шейки матки (конхотомом)</td><td></td><td>21,18 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Биопсия шейки матки (ножевая)</td><td></td><td>30,49 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Радиоволновая коагуляция (РВК)</td><td>45,13 BYN</td><td>71,82 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Радиоволновая конизация шейки матки</td><td>54,78 BYN</td><td>88,04 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Радиоволновая эксцизия шейки матки</td><td>54,78 BYN</td><td>88,04 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Радиоволновая биопсия шейки матки (ножевая, петлевая)</td><td>23,65 BYN</td><td>35,72 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Радиоволновая коагуляция кондилом вульвы, влагалища</td><td>40,85 BYN</td><td>65,00 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Радиоволновое иссечение кондилом вульвы, влагалища</td><td>54,78 BYN</td><td>88,04 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Выскабливание цервикального канала</td><td>22,63 BYN</td><td>34,52 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>УЗИ органов малого таза (трансабдоминально) с консультативным заключением </td><td>29,13 BYN</td><td>43,85 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>УЗИ органов малого таза (трансвагинально) с консультативным заключением</td><td>29,47 BYN</td><td>44,19 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>УЗИ молочных желез с консультативным заключением</td><td>34,01 BYN</td><td>52,73 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>УЗИ органов малого таза + УЗИ молочных желез с консультативным заключением</td><td>53,18 BYN</td><td>80,52 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>УЗИ молочных желез с регионарными лимфатическими узлами, с эластографией  и осмотром врача акушер-гинеколога или хирурга-онколога</td><td>40,90 BYN</td><td>60,56 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Комплексное оториноларингологическое обследование</td><td>51,69 BYN</td><td>116,00 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Промывание наружного слухового прохода</td><td>10,19 BYN</td><td>20,01 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Удаление серной пробки</td><td>18,09 BYN</td><td>47,88 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Удаление инородного тела из  уха</td><td></td><td>83,60 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Продувание слуховых труб по Политцеру (1 сеанс)</td><td></td><td>17,46 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Продувание слуховых труб (1 сеанс)</td><td>9,28 BYN</td><td>28,14 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Продувание слуховых труб катетером с введением лекарств (1 сеанс)</td><td></td><td>43,09 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Акуметрия (исследование слуха шепотной речью, камертонами)</td><td>7,34 BYN</td><td>22,23 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Промывание хронического уха аттиковой канюлей</td><td></td><td>42,27 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Массаж барабанной перепонки</td><td></td><td>13,97 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Пневмомассаж барабанной перепонки</td><td>4,59 BYN</td><td>14,03 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Туалет уха</td><td></td><td>14,04 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Вскрытие абсцедирующего фурункула наружного слухового прохода</td><td></td><td>57,77 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Обработка слизистой носа, глотки, гортани лекарственными препаратами</td><td></td><td>23,48 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Промывание лакун миндалин</td><td>19,38 BYN</td><td>44,54 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Удаление инородного тела гортаноглотки</td><td></td><td>98,52 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Инстилляция лекарственных средств в гортань</td><td>10,82 BYN</td><td>28,39 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Пункция верхнечелюстной пазухи</td><td></td><td>60,17 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Удаление инородного тела из носа</td><td></td><td>84,74 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Вскрытие абсцедирующих фурункулов носа</td><td></td><td>58,40 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Анемизация слизистой носа и носоглотки</td><td></td><td>22,79 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Анестезия слизистых</td><td></td><td>14,89 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Передняя тампонада носа</td><td></td><td>44,19 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Расширение перитонзиллярного абсцесса</td><td></td><td>46,93 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Вакуумный дренаж околоносовых пазух по Зондерману и Проетцу</td><td>25,08 BYN</td><td>61,71 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Вскрытие перитонзиллярных абсцессов</td><td></td><td>74,70 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Лечение синуитов при помощи синус-катетера "Ямик-321"</td><td></td><td>87,64 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Полипотомия носа</td><td></td><td>168,95 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Исследование уха под микроскопом</td><td></td><td>16,67 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Ультразвуковая вакуум санация лакун небных миндалин</td><td>24,54 BYN</td><td>57,89 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Видеоэндоскопия лор-органов</td><td>16,50 BYN</td><td>42,86 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Тимпанометрия</td><td>6,97 BYN</td><td>19,47 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Забор материала из носа на эозинофилы</td><td>5,05 BYN</td><td>13,99 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Забор материала из носа для микробиологического исследования</td><td>7,57 BYN</td><td>22,36 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Диагностика бета-гемолитического стрептококка группы А </td><td>22,41 BYN</td><td>25,63 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Вскрытие кисты небной миндалины</td><td></td><td>72,75 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Исследование полей зрения (периметрия)</td><td>16,64 BYN</td><td>39,42 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Комплексное офтальмологическое обследование</td><td>64,04 BYN</td><td></td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Компьютерная периметрия</td><td>37,35 BYN</td><td>91,16 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Измерение внутриглазного давления (тонометрия)</td><td>8,72 BYN</td><td>20,05 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Авторефрактокератометрия</td><td>12,60 BYN</td><td>29,61 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Гониоскопия</td><td>18,43 BYN</td><td>41,21 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Осмотр глазного дна с фундус линзой</td><td>27,10 BYN</td><td>61,21 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Ретиноскопия с видеорегистрацией</td><td>29,53 BYN</td><td>69,22 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Подбор очков (миопических, гиперметропических, астигматических, бифокальных, прогрессивных)</td><td>15,71 BYN</td><td>37,29 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Лазеркоагуляция сетчатки (один глаз)</td><td></td><td>223,67 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Массаж предстательной железы, получение секрета</td><td>7,17 BYN</td><td>15,17 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Взятие мазка из уретры</td><td>8,20 BYN</td><td>15,44 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Трансректальное пальцевое исследование простаты</td><td>9,50 BYN</td><td>15,65 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Лечебный массаж предстательной железы</td><td></td><td>15,17 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Взятие биологического материала для морфологического/цитологического исследования</td><td>6,10 BYN</td><td>8,35 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Электрокоагуляция 1 элемента доброкачественного новообразования кожи вирусной этиологии (бородавка, папиллома, контагиозный моллюск, кондилома)</td><td>11,60 BYN</td><td>15,84 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Электрокоагуляция доброкачественных новообразований кожи до 0,5см.</td><td>12,00 BYN</td><td>16,83 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Электрокоагуляция доброкачественных сосудистых новообразований кожи и красной и красной каймы губ за 1 кв.см.</td><td>17,00 BYN</td><td>28,75 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Электрокоагуляция доброкачественных новообразований кожи  и красной каймы губ от  0,5см.  до  1см. </td><td>20,00 BYN</td><td>30,73 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Удаление доброкачественных новообразований кожи и мягких тканей: фибромы(дерматофибромы), липомы, эпидермальные кисты (атеромы), папилломы, гигромы, ганглии и иные</td><td>76,00 BYN</td><td>125,00 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Локальная инъекционная ГКС терапия при болевом и воспалительном синдроме (без учета стоимости препарата)</td><td>26,02 BYN</td><td>40,63 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Внутрисуставная инъекционная ГКС терапия (коленные, локтевые, голеностопные) (без учета стоимости препарата)</td><td>30,63 BYN</td><td>45,24 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Внутрисуставная инъекционная ГКС терапия (тазобедренные/плечевые) (без учета стоимости препарата)</td><td>35,25 BYN</td><td>50,62 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Локальная инъекционной ГКС терапия при поражениях периартикулярных тканей при болевом синдроме (без учета стоимости препарата)</td><td>26,02 BYN</td><td>40,63 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Внутрисуставное введение препаратов гиалуроновой кислоты (коленные, локтевые, голеностопные) (без учета стоимости препарата)</td><td>30,53 BYN</td><td>45,14 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Внутрисуставное введение препаратов гиалуроновой кислоты (тазобедренные/плечевые) (без учета стоимости препарата)</td><td>35,15 BYN</td><td>50,52 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Периартикулярное введение препаратов гиалуроновой кислоты (без учета стоимости препарата)</td><td>25,92 BYN</td><td>40,53 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Внутрисуставное введение лекарственного средства при поражениях коленного, локтевого и т.д. суставов под УЗИ-контролем (без учета соимости лекарственного средства)</td><td>49,48 BYN</td><td>69,48 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Внутрисуставное введение лекарственного средства при поражениях тазобедренного и плечевого суставов под УЗИ-контролем (без учета соимости лекарственного средства)</td><td>54,42 BYN</td><td>74,18 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Локальная инъекционная ГКС терапия болевого синдрома при поражениях паравертебральных тканей (без учета стоимости препарата)</td><td>25,07 BYN</td><td>39,40 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Локальная инъекционная ГКС терапия при туннельных невропатиях (без учета стоимости препарата)</td><td>25,07 BYN</td><td>39,40 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Удаление части ногтевой пластины с пластикой околоногтевого валика</td><td>72,50 BYN</td><td>112,50 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Удаление патологических рубцов кожи тела (до 10 см)</td><td>100,00 BYN</td><td>120,00 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Чрескожная диагностическая биопсия молочной железы</td><td>48,85 BYN</td><td>62,00 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Чрескожная диагностическая биопсия лимфоузла</td><td>48,85 BYN</td><td>62,00 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Малоинвазивный метод лечения при поражениях суставов с помощью аутоплазмы, обогащенной тромбоцитарной массой, под УЗИ-контролем (PRP-терапия)</td><td>121,10 BYN</td><td>190,00 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>ГИАЛ-СИН - раствор для внутрисуставного введения (20мг/2мл)</td><td>64,13 BYN</td><td>64,13 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>ГИАЛ-СИН - ПРОЛОНГ - раствор для внутрисуставного введения (40мг/2мл)</td><td>160,16 BYN</td><td>160,16 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Дипроспан - раствор для внутрисуставного введения</td><td>13,89 BYN</td><td>13,89 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Раствор инъекционный "ГИАЛ-ИН"(25мг/2,5мл)</td><td>49,45 BYN</td><td>49,45 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>РЕБОСПАН - раствор для внутрисуставного введения</td><td>8,45 BYN</td><td>8,45 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>РИВАКСАН 15МГ</td><td>3,46 BYN</td><td>3,46 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>ГИАЛ-СИН - раствор для внутрисуставного введения (20мг/2мл) (ПРОТЕЗИРОВАНИЕ)</td><td>55,00 BYN</td><td>55,00 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>ГИАЛ-СИН - ПРОЛОНГ - раствор для внутрисуставного введения (40мг/2мл) (ПРОТЕЗИРОВАНИЕ)</td><td>140,00 BYN</td><td>140,00 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>ДИПРАЗОН суспензия для инъекций</td><td>11,61 BYN</td><td>11,61 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td class="table-list__title-wrapper" colspan="3">
# <div class="table-list__title">Радиочастотная облитерация</div>
# </td>
# </tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Минифлебэктомия (1 нога)</td><td>600,12 BYN</td><td>600,12 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Минифлебэктомия (2 ноги)</td><td>1 087,48 BYN</td><td>1 087,48 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Радиочастотная облитерация стволов подкожных вен в сочетании с минифлебэктомией (1 нога) </td><td>1 760,72 BYN</td><td>1 760,72 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Радиочастотная облитерация стволов подкожных вен (1 нога)</td><td>1 292,04 BYN</td><td>1 292,04 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Радиочастотная облитерация стволов подкожных вен (2 ноги) </td><td>1 476,24 BYN</td><td>1 476,24 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Радиочастотная облитерация двух стволов подкожых вен  2-ух ног в сочетании  с минифлебэктомией одной ноги</td><td>2 015,36 BYN</td><td>2 015,36 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Радиочастотная облитерация  стволов подкожых вен в сочетании с минифлебэктомией двух ног.(2 РЧА+2 минифлебэктомии) </td><td>2 347,90 BYN</td><td>2 347,90 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td class="table-list__title-wrapper" colspan="3">
# <div class="table-list__title">Склеротерапия</div>
# </td>
# </tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Склеротерапия крупных вен и вен среднего калибра одной области (бедра либо голени), одной поверхности (передней, задней, внутренней, наружной) с применением пенной формы склерозанта, вводимого под УЗ-контролем (без учета стоимости склерозанта). Одна зона.</td><td>57,58 BYN</td><td>82,57 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Склеротерапия крупных вен и вен среднего калибра с применением пенной формы склерозанта, вводимого под УЗ-контролем (без учета стоимости склерозанта). Две зоны</td><td>100,20 BYN</td><td>150,18 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Склеротерапия крупных вен и вен среднего калибра с применением пенной формы склерозанта, вводимого под УЗ-контролем (без учета стоимости склерозанта). Три зоны</td><td>142,82 BYN</td><td>217,79 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Склеротерапия телеангиэктазий и ретикулярных вен на площади до 100 см2 (10*10 см) с применением пенной формы склерозанта, вводимого под УЗ-контролем (без учета стоимости склерозанта). Одна зона</td><td>57,58 BYN</td><td>82,57 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Склеротерапия телеангиэктазий и ретикулярных вен с применением пенной формы склерозанта, вводимого под УЗ-контролем (без учета стоимости склерозанта). Две зоны</td><td>100,20 BYN</td><td>150,18 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Склеротерапия телеангиэктазий и ретикулярных вен с применением пенной формы склерозанта, вводимого под УЗ-контролем (без учета стоимости склерозанта). Три зоны</td><td>142,82 BYN</td><td>217,79 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Доплата к склеротерапии за этоксисклерол</td><td>16,24 BYN</td><td>16,24 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td class="table-list__title-wrapper" colspan="3">
# <div class="table-list__title">Отдельные операции</div>
# </td>
# </tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Взятие крови из вены</td><td>2,57 BYN</td><td>4,92 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Доплата за одноразовую пробирку для забора крови, 8 мл</td><td>0,52 BYN</td><td>0,52 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Доплата за одноразовую пробирку для забора крови, 3 мл</td><td>0,27 BYN</td><td>0,27 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Доплата за одноразовую пробирку для забора крови, 4,5 мл</td><td>0,30 BYN</td><td>0,30 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Доплата за одноразовую пробирку для забора крови, 9 мл (аллергены)</td><td>0,43 BYN</td><td>0,43 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Забор крови на дому</td><td>20,92 BYN</td><td></td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Обработка венозной крови для получения сыворотки</td><td>0,62 BYN</td><td>2,30 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Обработка венозной крови для получения плазмы</td><td>0,62 BYN</td><td>2,30 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td class="table-list__title-wrapper" colspan="3">
# <div class="table-list__title">Общеклинические исследования</div>
# </td>
# </tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Общий анализ мочи</td><td>3,63 BYN</td><td>6,24 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Анализ мочи по Нечипоренко</td><td>3,59 BYN</td><td>6,92 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Анализ мочи на микроальбуминурию</td><td>3,54 BYN</td><td>4,28 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>А-амилаза в моче</td><td>2,10 BYN</td><td>3,17 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Исследование секрета предстательной железы</td><td>2,17 BYN</td><td>5,82 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Гинекологический мазок на флору, гонорею, трихомонады</td><td>4,57 BYN</td><td>9,49 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Исследование эякулята человека на анализаторе качества спермы SQA-V</td><td>46,78 BYN</td><td>59,37 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Определение скорости свертывания крови</td><td>4,04 BYN</td><td>7,34 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Определение калия, натрия, кальция ионизированного</td><td>3,65 BYN</td><td>6,26 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Определение калия, натрия, хлор</td><td>3,65 BYN</td><td>6,26 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Определение глюкозы в капиллярной крови</td><td>3,88 BYN</td><td>6,48 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Гликированный гемоглобин</td><td>14,28 BYN</td><td>17,65 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Глюкозотолерантный тест</td><td>12,08 BYN</td><td>19,88 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Экспресс-анализ антиспер-мальных антител в сперме (MAR-тест) количественный, антитела класса иммуноглобулина А</td><td>29,14 BYN</td><td>39,51 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Экспресс-анализ антиспер-мальных антител в сперме. (MAR-тест) количественный, антитела класса иммуноглобулина G</td><td>29,14 BYN</td><td>39,51 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td class="table-list__title-wrapper" colspan="3">
# <div class="table-list__title">Гематологические исследования</div>
# </td>
# </tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Общий анализ крови с ручной микроскопией мазка крови</td><td>13,11 BYN</td><td>19,90 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Общий анализ крови</td><td>10,63 BYN</td><td>14,52 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Общий анализ крови из вены с ручной микроскопией мазка крови</td><td>10,65 BYN</td><td>15,98 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Общий анализ крови из вены</td><td>8,17 BYN</td><td>10,60 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Подсчет ретикулацитов</td><td>5,46 BYN</td><td>11,09 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td class="table-list__title-wrapper" colspan="3">
# <div class="table-list__title">Цитологические исследования</div>
# </td>
# </tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Цитологическое исследование материала одного образования пункционной биопсии (или щитовидной железы, или молочной железы)</td><td>20,19 BYN</td><td>57,24 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Цитологическое исследование материала двух образований пункционной биопсии (или щитовидной железы, или молочной железы)</td><td>49,79 BYN</td><td>114,29 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Цитологическое исследование гинекологического мазка</td><td>6,19 BYN</td><td>12,69 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Цитологическое исследование эндоскопического материала</td><td>7,82 BYN</td><td>16,50 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Цитологическое исследование экссудата молочной железы</td><td>5,60 BYN</td><td>11,42 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Цитологическое исследование материала с поверхности кожи или слизистой</td><td>5,60 BYN</td><td>11,42 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td class="table-list__title-wrapper" colspan="3">
# <div class="table-list__title">Биохимические исследования</div>
# </td>
# </tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Аспартатаминотрансаминаза AST</td><td>1,35 BYN</td><td>2,06 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Аланинаминотрансфераза ALT</td><td>1,35 BYN</td><td>2,06 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Общая железосвязывающая способность ОЖСС</td><td>1,96 BYN</td><td>2,67 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Гаммаглутамилтрансфераза</td><td>1,42 BYN</td><td>2,13 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Щелочная фосфотаза</td><td>1,68 BYN</td><td>2,39 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Лактатдегидрогеназа LDH</td><td>1,38 BYN</td><td>2,09 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Общий белок</td><td>1,35 BYN</td><td>2,06 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Общий билирубин</td><td>1,45 BYN</td><td>2,16 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Прямой билирубин</td><td>1,43 BYN</td><td>2,14 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Мочевина</td><td>1,50 BYN</td><td>2,21 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>А-амилаза</td><td>1,95 BYN</td><td>2,66 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Триглицериды</td><td>1,91 BYN</td><td>2,62 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Альбумины</td><td>1,37 BYN</td><td>2,08 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Мочевая кислота</td><td>1,54 BYN</td><td>2,25 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Глюкоза</td><td>1,45 BYN</td><td>2,16 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Кальций общий</td><td>1,51 BYN</td><td>2,22 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Фосфор</td><td>1,37 BYN</td><td>2,08 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Креатинин</td><td>1,28 BYN</td><td>1,99 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Холестерин общий</td><td>1,64 BYN</td><td>2,35 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Железо</td><td>1,60 BYN</td><td>2,31 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Магний</td><td>2,23 BYN</td><td>2,94 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Креатинкиназа СК</td><td>1,77 BYN</td><td>2,48 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>H D L Холестерин высокой плотности</td><td>2,63 BYN</td><td>3,34 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>L D L Холестерин низкой плотности</td><td>3,83 BYN</td><td>4,54 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Панкреатическая амилаза</td><td>3,17 BYN</td><td>3,88 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Липаза</td><td>1,85 BYN</td><td>2,56 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Креатинкиназа - МВ (сердечная фракция креатинкиназы)</td><td>2,33 BYN</td><td>3,04 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Церулоплазмин</td><td>6,84 BYN</td><td>7,55 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Д-Димер</td><td>14,69 BYN</td><td>15,40 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Аполипопротеины АроВТ</td><td>5,39 BYN</td><td>6,10 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Аполипопротеины АроАТ</td><td>5,64 BYN</td><td>6,35 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Ревматоидный фактор</td><td>3,05 BYN</td><td>3,76 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>С-реактивный белок</td><td>6,20 BYN</td><td>6,91 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Антистрептолизин-О общий</td><td>6,85 BYN</td><td>7,56 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Ферритин</td><td>4,39 BYN</td><td>5,10 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Трансферрин</td><td>2,91 BYN</td><td>3,62 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Цистатин С</td><td>10,15 BYN</td><td>10,86 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td class="table-list__title-wrapper" colspan="3">
# <div class="table-list__title">Определение гормонов методом иммуноферментного анализа на иммуноферментном анализаторе ARCHITECT</div>
# </td>
# </tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>ИФА количественное определение антител Ig G к вирусу SARS-CoV-2 на анализаторе ARCHITECT</td><td>36,08 BYN</td><td>41,71 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>ИФА Витамин D3</td><td>40,59 BYN</td><td>46,22 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>ИФА Секссвязывающий глобулин</td><td>29,26 BYN</td><td>34,89 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>ИФА Антитела к циклическому цитруллиновому пептиду Anti- CCP</td><td>30,58 BYN</td><td>36,21 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>ИФА Антитела к вирусу Гепатита С Anti-HCV</td><td>28,65 BYN</td><td>34,28 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>ИФА Качественный подтверждающий антиген гепатита В (Hbs Ag)</td><td>21,56 BYN</td><td>27,19 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>ИФА ПСА-общий</td><td>18,46 BYN</td><td>24,09 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>ИФА ПСА-свободный</td><td>19,60 BYN</td><td>25,23 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>ИФА СА 125</td><td>24,29 BYN</td><td>29,92 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>ИФА НЕ 4</td><td>39,61 BYN</td><td>45,24 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>ИФА В12 (цианокобаламин)</td><td>19,87 BYN</td><td>25,50 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>ИФА Фолиевая кислота</td><td>13,58 BYN</td><td>19,21 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>ИФА Антитела IgG к токсоплазме</td><td>21,27 BYN</td><td>26,90 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>ИФА Антитела IgM к токсоплазме</td><td>25,02 BYN</td><td>30,65 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>ИФА Антитела IgM к цитомегаловирусу</td><td>27,06 BYN</td><td>32,69 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>ИФА Антитела IgG к вирусу краснухи</td><td>20,75 BYN</td><td>26,38 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>ИФА Антитела IgM к вирусу краснухи</td><td>24,22 BYN</td><td>29,85 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>ИФА Гомоцистеин</td><td>29,29 BYN</td><td>34,92 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>ИФА Альфафетопротеин</td><td>16,64 BYN</td><td>22,27 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>ИФА Бета-хорионический гонадотропин (ХГЧ)</td><td>15,20 BYN</td><td>20,83 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>ИФА Раковоэмбриональный антиген</td><td>18,26 BYN</td><td>23,89 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td class="table-list__title-wrapper" colspan="3">
# <div class="table-list__title">Определение гормонов методом иммуноферментного анализа на иммуноферментном анализаторе BRIO</div>
# </td>
# </tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>ИФА Метанефрины (метанефрин, норметанефрин) в плазме</td><td>49,18 BYN</td><td>55,49 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>ИФА Инсулин антитела IAA</td><td>17,43 BYN</td><td>23,74 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>ИФА Интра-клеточные антитела ICA</td><td>44,22 BYN</td><td>50,53 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>ИФА GAD-65</td><td>38,36 BYN</td><td>44,67 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>ИФА Тестостерон свободный</td><td>17,78 BYN</td><td>24,09 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>ИФА Альдостерон (сидя/лежа)</td><td>18,91 BYN</td><td>25,22 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>ИФА 17-ОН Прогестерон</td><td>11,35 BYN</td><td>17,66 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>ИФА Ренин</td><td>25,29 BYN</td><td>31,60 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>ИФА Кортизол в моче</td><td>17,66 BYN</td><td>23,79 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>ИФА Кортизол в слюне</td><td>18,39 BYN</td><td>24,70 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>ИФА Витамин Д общий</td><td>27,90 BYN</td><td>34,21 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td class="table-list__title-wrapper" colspan="3">
# <div class="table-list__title">Исследование состояния гемостаза</div>
# </td>
# </tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Определение активированного частичного тромбопластинового времени АЧТВ</td><td>7,84 BYN</td><td>15,66 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Определение протромбинового времени ― ПВ с расчетом международного нормализованного времени МНО</td><td>7,86 BYN</td><td>15,44 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Определение количества фибриногена</td><td>8,67 BYN</td><td>16,25 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td class="table-list__title-wrapper" colspan="3">
# <div class="table-list__title">Бактериологические исследования</div>
# </td>
# </tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Исследование гинекологических мазков на урогенитальную патологию с идентификацией бактерий и определением их чувствительности к антибиотикам</td><td>28,92 BYN</td><td>37,28 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# <td>Мазок из носоглотки или носа на эозинофилию, микоз (соскоб на грибы)</td><td>4,57 BYN</td><td>10,44 BYN</td></tr>
# row - for row in tag.find(name="tbody").find_all("tr"): <tr>
# ...
#   'analisys_cost': '69,55 BYN',
#   'analisys_comment': 'ФОТОЭПИЛЯЦИЯ'},
#  724: {'source': 'makaenka17med.by',
#   'chapter': 'КОСМЕТОЛОГИЯ, ДЕРМАТОЛОГИЯ, ТРИХОЛОГИЯ\n\n\n',
#   'analisys_name': 'Фотоэпиляция области грудной клетки',
#   'analisys_cost': '91,75 BYN',
#   'analisys_comment': 'ФОТОЭПИЛЯЦИЯ'},
#  725: {'source': 'makaenka17med.by',
#   'chapter': 'КОСМЕТОЛОГИЯ, ДЕРМАТОЛОГИЯ, ТРИХОЛОГИЯ\n\n\n',
#   'analisys_name': 'Фотоэпиляция плеч',
#   'analisys_cost': '59,17 BYN',
#   'analisys_comment': 'ФОТОЭПИЛЯЦИЯ'},
#  726: {'source': 'makaenka17med.by',
#   'chapter': 'КОСМЕТОЛОГИЯ, ДЕРМАТОЛОГИЯ, ТРИХОЛОГИЯ\n\n\n',
#   'analisys_name': 'Фотоэпиляция предплечий',
#   'analisys_cost': '59,17 BYN',
#   'analisys_comment': 'ФОТОЭПИЛЯЦИЯ'},
#  727: {'source': 'makaenka17med.by',
#   'chapter': 'КОСМЕТОЛОГИЯ, ДЕРМАТОЛОГИЯ, ТРИХОЛОГИЯ\n\n\n',
#   'analisys_name': 'Фотодеструкция интрадермальной гиперпигментации (трафарет 5х7см)',
#   'analisys_cost': '34,28 BYN',
#   'analisys_comment': 'ФОТООМОЛОЖЕНИЕ, ФОТОЛЕЧЕНИЕ'},
#  728: {'source': 'makaenka17med.by',
#   'chapter': 'КОСМЕТОЛОГИЯ, ДЕРМАТОЛОГИЯ, ТРИХОЛОГИЯ\n\n\n',
#   'analisys_name': 'Удаление единичных сосудистых звездочек / телеангиоэктазий (до 4 шт.)',
#   'analisys_cost': '23,71 BYN',
#   'analisys_comment': 'ФОТООМОЛОЖЕНИЕ, ФОТОЛЕЧЕНИЕ'},
#  729: {'source': 'makaenka17med.by',
#   'chapter': 'КОСМЕТОЛОГИЯ, ДЕРМАТОЛОГИЯ, ТРИХОЛОГИЯ\n\n\n',
#   'analisys_name': 'Удаление единичных сосудистых звездочек / телеангиоэктазий за 1 шт свыше 4-х шт',
#   'analisys_cost': '5,25 BYN',
#   'analisys_comment': 'ФОТООМОЛОЖЕНИЕ, ФОТОЛЕЧЕНИЕ'},
#  730: {'source': 'makaenka17med.by',
#   'chapter': 'КОСМЕТОЛОГИЯ, ДЕРМАТОЛОГИЯ, ТРИХОЛОГИЯ\n\n\n',
#   'analisys_name': 'Устранение сосудистых дефектов в области крыльев носа (купероз)',
#   'analisys_cost': '29,12 BYN',
#   'analisys_comment': 'ФОТООМОЛОЖЕНИЕ, ФОТОЛЕЧЕНИЕ'},
#  731: {'source': 'makaenka17med.by',
#   'chapter': 'КОСМЕТОЛОГИЯ, ДЕРМАТОЛОГИЯ, ТРИХОЛОГИЯ\n\n\n',
#   'analisys_name': 'Фотолечение возрастных изменений кожи лица',
#   'analisys_cost': '112,61 BYN',
#   'analisys_comment': 'ФОТООМОЛОЖЕНИЕ, ФОТОЛЕЧЕНИЕ'},
#  732: {'source': 'makaenka17med.by',
#   'chapter': 'КОСМЕТОЛОГИЯ, ДЕРМАТОЛОГИЯ, ТРИХОЛОГИЯ\n\n\n',
#   'analisys_name': 'Фотолечение возрастных изменений кожи в области щек.',
#   'analisys_cost': '70,28 BYN',
#   'analisys_comment': 'ФОТООМОЛОЖЕНИЕ, ФОТОЛЕЧЕНИЕ'},
#  733: {'source': 'makaenka17med.by',
#   'chapter': 'КОСМЕТОЛОГИЯ, ДЕРМАТОЛОГИЯ, ТРИХОЛОГИЯ\n\n\n',
#   'analisys_name': 'Фотолечение возрастных изменений кожи в лобной области ',
#   'analisys_cost': '70,28 BYN',
#   'analisys_comment': 'ФОТООМОЛОЖЕНИЕ, ФОТОЛЕЧЕНИЕ'},
#  734: {'source': 'makaenka17med.by',
#   'chapter': 'КОСМЕТОЛОГИЯ, ДЕРМАТОЛОГИЯ, ТРИХОЛОГИЯ\n\n\n',
#   'analisys_name': 'Фотолечение возрастных изменений кожи в области носа',
#   'analisys_cost': '40,96 BYN',
#   'analisys_comment': 'ФОТООМОЛОЖЕНИЕ, ФОТОЛЕЧЕНИЕ'},
#  735: {'source': 'makaenka17med.by',
#   'chapter': 'КОСМЕТОЛОГИЯ, ДЕРМАТОЛОГИЯ, ТРИХОЛОГИЯ\n\n\n',
#   'analisys_name': 'Фотолечение возрастных изменений кожи в подбородочной области',
#   'analisys_cost': '29,12 BYN',
#   'analisys_comment': 'ФОТООМОЛОЖЕНИЕ, ФОТОЛЕЧЕНИЕ'},
#  736: {'source': 'makaenka17med.by',
#   'chapter': 'КОСМЕТОЛОГИЯ, ДЕРМАТОЛОГИЯ, ТРИХОЛОГИЯ\n\n\n',
#   'analisys_name': 'Фотолечение возрастных изменений кожи в области шеи',
#   'analisys_cost': '70,28 BYN',
#   'analisys_comment': 'ФОТООМОЛОЖЕНИЕ, ФОТОЛЕЧЕНИЕ'},
#  737: {'source': 'makaenka17med.by',
#   'chapter': 'КОСМЕТОЛОГИЯ, ДЕРМАТОЛОГИЯ, ТРИХОЛОГИЯ\n\n\n',
#   'analisys_name': 'Фотолечение возрастных изменений кожи в области передней поверхности грудной клетки',
#   'analisys_cost': '91,98 BYN',
#   'analisys_comment': 'ФОТООМОЛОЖЕНИЕ, ФОТОЛЕЧЕНИЕ'},
#  738: {'source': 'makaenka17med.by',
#   'chapter': 'КОСМЕТОЛОГИЯ, ДЕРМАТОЛОГИЯ, ТРИХОЛОГИЯ\n\n\n',
#   'analisys_name': 'Фотолечение возрастных изменений кожи тыльной поверхности кистей',
#   'analisys_cost': '68,11 BYN',
#   'analisys_comment': 'ФОТООМОЛОЖЕНИЕ, ФОТОЛЕЧЕНИЕ'},
#  739: {'source': 'makaenka17med.by',
#   'chapter': 'КОСМЕТОЛОГИЯ, ДЕРМАТОЛОГИЯ, ТРИХОЛОГИЯ\n\n\n',
#   'analisys_name': 'Фотолечение возрастных изменений в области лица, передней поверхности шеи, декольте, кистей',
#   'analisys_cost': '200,12 BYN',
#   'analisys_comment': 'ФОТООМОЛОЖЕНИЕ, ФОТОЛЕЧЕНИЕ'},
#  740: {'source': 'makaenka17med.by',
#   'chapter': 'КОСМЕТОЛОГИЯ, ДЕРМАТОЛОГИЯ, ТРИХОЛОГИЯ\n\n\n',
#   'analisys_name': 'Неаблятивное лазерное омоложение кожи периорбитальной области (глаза)',
#   'analisys_cost': '109,84 BYN',
#   'analisys_comment': 'ЛАЗЕРНОЕ ОМОЛОЖЕНИЕ'},
#  741: {'source': 'makaenka17med.by',
#   'chapter': 'КОСМЕТОЛОГИЯ, ДЕРМАТОЛОГИЯ, ТРИХОЛОГИЯ\n\n\n',
#   'analisys_name': 'Неаблятивное лазерное омоложение кожи щек',
#   'analisys_cost': '110,46 BYN',
#   'analisys_comment': 'ЛАЗЕРНОЕ ОМОЛОЖЕНИЕ'},
#  742: {'source': 'makaenka17med.by',
#   'chapter': 'КОСМЕТОЛОГИЯ, ДЕРМАТОЛОГИЯ, ТРИХОЛОГИЯ\n\n\n',
#   'analisys_name': 'Неаблятивное лазерное омоложение кожи передней поверхности шеи',
#   'analisys_cost': '110,46 BYN',
#   'analisys_comment': 'ЛАЗЕРНОЕ ОМОЛОЖЕНИЕ'},
#  743: {'source': 'makaenka17med.by',
#   'chapter': 'КОСМЕТОЛОГИЯ, ДЕРМАТОЛОГИЯ, ТРИХОЛОГИЯ\n\n\n',
#   'analisys_name': 'Неаблятивное лазерное омоложение кожи декольте',
#   'analisys_cost': '150,91 BYN',
#   'analisys_comment': 'ЛАЗЕРНОЕ ОМОЛОЖЕНИЕ'},
#  744: {'source': 'makaenka17med.by',
#   'chapter': 'КОСМЕТОЛОГИЯ, ДЕРМАТОЛОГИЯ, ТРИХОЛОГИЯ\n\n\n',
#   'analisys_name': 'Неаблятивное лазерное омоложение кожи лица полностью',
#   'analisys_cost': '201,14 BYN',
#   'analisys_comment': 'ЛАЗЕРНОЕ ОМОЛОЖЕНИЕ'},
#  745: {'source': 'makaenka17med.by',
#   'chapter': 'КОСМЕТОЛОГИЯ, ДЕРМАТОЛОГИЯ, ТРИХОЛОГИЯ\n\n\n',
#   'analisys_name': 'Неаблятивное лазерное омо-ложение кожи лица, передней поверхности шеи',
#   'analisys_cost': '273,07 BYN',
#   'analisys_comment': 'ЛАЗЕРНОЕ ОМОЛОЖЕНИЕ'},
#  746: {'source': 'makaenka17med.by',
#   'chapter': 'КОСМЕТОЛОГИЯ, ДЕРМАТОЛОГИЯ, ТРИХОЛОГИЯ\n\n\n',
#   'analisys_name': 'Неаблятивное лазерное омоложение кожи лица, передней поверхности шеи, декольте',
#   'analisys_cost': '374,83 BYN',
#   'analisys_comment': 'ЛАЗЕРНОЕ ОМОЛОЖЕНИЕ'},
#  747: {'source': 'makaenka17med.by',
#   'chapter': 'КОСМЕТОЛОГИЯ, ДЕРМАТОЛОГИЯ, ТРИХОЛОГИЯ\n\n\n',
#   'analisys_name': 'Лазерная коррекция рубцов, растяжек до 2 см',
#   'analisys_cost': '23,27 BYN',
#   'analisys_comment': 'ЛАЗЕРНАЯ КОРРЕКЦИЯ РУБЦОВ  '},
#  748: {'source': 'makaenka17med.by',
#   'chapter': 'КОСМЕТОЛОГИЯ, ДЕРМАТОЛОГИЯ, ТРИХОЛОГИЯ\n\n\n',
#   'analisys_name': 'Лазерная коррекция шрамов, рубцов за каждый последующий 1 см',
#   'analisys_cost': '11,56 BYN',
#   'analisys_comment': 'ЛАЗЕРНАЯ КОРРЕКЦИЯ РУБЦОВ  '},
#  749: {'source': 'makaenka17med.by',
#   'chapter': 'КОСМЕТОЛОГИЯ, ДЕРМАТОЛОГИЯ, ТРИХОЛОГИЯ\n\n\n',
#   'analisys_name': 'Лазерная коррекция растяжек в области ягодиц',
#   'analisys_cost': '170,53 BYN',
#   'analisys_comment': 'ЛАЗЕРНАЯ КОРРЕКЦИЯ РУБЦОВ  '},
#  750: {'source': 'makaenka17med.by',
#   'chapter': 'КОСМЕТОЛОГИЯ, ДЕРМАТОЛОГИЯ, ТРИХОЛОГИЯ\n\n\n',
#   'analisys_name': 'Лазерная коррекция растяжек в области живота',
#   'analisys_cost': '169,80 BYN',
#   'analisys_comment': 'ЛАЗЕРНАЯ КОРРЕКЦИЯ РУБЦОВ  '},
#  751: {'source': 'makaenka17med.by',
#   'chapter': 'КОСМЕТОЛОГИЯ, ДЕРМАТОЛОГИЯ, ТРИХОЛОГИЯ\n\n\n',
#   'analisys_name': 'Лазерная коррекция растяжек в области груди',
#   'analisys_cost': '159,91 BYN',
#   'analisys_comment': 'ЛАЗЕРНАЯ КОРРЕКЦИЯ РУБЦОВ  '},
#  752: {'source': 'makaenka17med.by',
#   'chapter': 'КОСМЕТОЛОГИЯ, ДЕРМАТОЛОГИЯ, ТРИХОЛОГИЯ\n\n\n',
#   'analisys_name': 'Лазерное стимулирование роста волос (волосистая часть головы полностью)',
#   'analisys_cost': '151,25 BYN',
#   'analisys_comment': 'ЛАЗЕРНОЕ СТИМУЛИРОВАНИЕ РОСТА ВОЛОС'},
#  753: {'source': 'makaenka17med.by',
#   'chapter': 'КОСМЕТОЛОГИЯ, ДЕРМАТОЛОГИЯ, ТРИХОЛОГИЯ\n\n\n',
#   'analisys_name': 'Лазерное стимулирование роста волос (лобнотеменная область)',
#   'analisys_cost': '93,50 BYN',
#   'analisys_comment': 'ЛАЗЕРНОЕ СТИМУЛИРОВАНИЕ РОСТА ВОЛОС'},
#  754: {'source': 'makaenka17med.by',
#   'chapter': 'КОСМЕТОЛОГИЯ, ДЕРМАТОЛОГИЯ, ТРИХОЛОГИЯ\n\n\n',
#   'analisys_name': 'Лазерное стимулирование роста волос (затылочная область)',
#   'analisys_cost': '79,38 BYN',
#   'analisys_comment': 'ЛАЗЕРНОЕ СТИМУЛИРОВАНИЕ РОСТА ВОЛОС'},
#  755: {'source': 'makaenka17med.by',
#   'chapter': 'КОСМЕТОЛОГИЯ, ДЕРМАТОЛОГИЯ, ТРИХОЛОГИЯ\n\n\n',
#   'analisys_name': 'Лазерное стимулирование роста волос (височные области)',
#   'analisys_cost': '79,38 BYN',
#   'analisys_comment': 'ЛАЗЕРНОЕ СТИМУЛИРОВАНИЕ РОСТА ВОЛОС'},
#  756: {'source': 'makaenka17med.by',
#   'chapter': 'КОСМЕТОЛОГИЯ, ДЕРМАТОЛОГИЯ, ТРИХОЛОГИЯ\n\n\n',
#   'analisys_name': 'Сочетание лазерного модуля и модуля IPL в одну процедуру (щеки)',
#   'analisys_cost': '161,68 BYN',
#   'analisys_comment': 'СОЧЕТАНИЕ ЛАЗЕРНОГО МОДУЛЯ И МОДУЛЯ IPL В ОДНУ ПРОЦЕДУРУ'},
#  757: {'source': 'makaenka17med.by',
#   'chapter': 'КОСМЕТОЛОГИЯ, ДЕРМАТОЛОГИЯ, ТРИХОЛОГИЯ\n\n\n',
#   'analisys_name': 'Сочетание лазерного модуля и модуля IPL в одну процедуру (шея)',
#   'analisys_cost': '160,87 BYN',
#   'analisys_comment': 'СОЧЕТАНИЕ ЛАЗЕРНОГО МОДУЛЯ И МОДУЛЯ IPL В ОДНУ ПРОЦЕДУРУ'},
#  758: {'source': 'makaenka17med.by',
#   'chapter': 'КОСМЕТОЛОГИЯ, ДЕРМАТОЛОГИЯ, ТРИХОЛОГИЯ\n\n\n',
#   'analisys_name': 'Сочетание лазерного модуля и модуля IPL в одну процедуру (декольте)',
#   'analisys_cost': '201,72 BYN',
#   'analisys_comment': 'СОЧЕТАНИЕ ЛАЗЕРНОГО МОДУЛЯ И МОДУЛЯ IPL В ОДНУ ПРОЦЕДУРУ'},
#  759: {'source': 'makaenka17med.by',
#   'chapter': 'КОСМЕТОЛОГИЯ, ДЕРМАТОЛОГИЯ, ТРИХОЛОГИЯ\n\n\n',
#   'analisys_name': 'Сочетание лазерного модуля и модуля IPL в одну процедуру (лицо полностью)',
#   'analisys_cost': '274,42 BYN',
#   'analisys_comment': 'СОЧЕТАНИЕ ЛАЗЕРНОГО МОДУЛЯ И МОДУЛЯ IPL В ОДНУ ПРОЦЕДУРУ'},
#  760: {'source': 'makaenka17med.by',
#   'chapter': 'КОСМЕТОЛОГИЯ, ДЕРМАТОЛОГИЯ, ТРИХОЛОГИЯ\n\n\n',
#   'analisys_name': 'Сочетание лазерного модуля и модуля IPL в одну процедуру (лицо, шея)',
#   'analisys_cost': '436,59 BYN',
#   'analisys_comment': 'СОЧЕТАНИЕ ЛАЗЕРНОГО МОДУЛЯ И МОДУЛЯ IPL В ОДНУ ПРОЦЕДУРУ'},
#  761: {'source': 'makaenka17med.by',
#   'chapter': 'КОСМЕТОЛОГИЯ, ДЕРМАТОЛОГИЯ, ТРИХОЛОГИЯ\n\n\n',
#   'analisys_name': 'Сочетание лазерного модуля и модуля IPL в одну процедуру (лицо, шея, декольте)',
#   'analisys_cost': '569,61 BYN',
#   'analisys_comment': 'СОЧЕТАНИЕ ЛАЗЕРНОГО МОДУЛЯ И МОДУЛЯ IPL В ОДНУ ПРОЦЕДУРУ'},
#  762: {'source': 'makaenka17med.by',
#   'chapter': 'КОСМЕТОЛОГИЯ, ДЕРМАТОЛОГИЯ, ТРИХОЛОГИЯ\n\n\n',
#   'analisys_name': 'Трихоскопия',
#   'analisys_cost': '47,65 BYN',
#   'analisys_comment': 'ТРИХОСКОПИЯ'},
#  763: {'source': 'makaenka17med.by',
#   'chapter': 'КОСМЕТОЛОГИЯ, ДЕРМАТОЛОГИЯ, ТРИХОЛОГИЯ\n\n\n',
#   'analisys_name': 'Дерматоскопия до 3-х элементов',
#   'analisys_cost': '20,44 BYN',
#   'analisys_comment': 'ТРИХОСКОПИЯ'},
#  764: {'source': 'makaenka17med.by',
#   'chapter': 'КОСМЕТОЛОГИЯ, ДЕРМАТОЛОГИЯ, ТРИХОЛОГИЯ\n\n\n',
#   'analisys_name': 'Дерматоскопия от 4-х до 10-и эле-ментов',
#   'analisys_cost': '29,13 BYN',
#   'analisys_comment': 'ТРИХОСКОПИЯ'},
#  765: {'source': 'makaenka17med.by',
#   'chapter': 'КОСМЕТОЛОГИЯ, ДЕРМАТОЛОГИЯ, ТРИХОЛОГИЯ\n\n\n',
#   'analisys_name': 'Дерматоскопия свыше 10-и элементов',
#   'analisys_cost': '57,74 BYN',
#   'analisys_comment': 'ТРИХОСКОПИЯ'},
#  766: {'source': 'makaenka17med.by',
#   'chapter': 'СТОМАТОЛОГИЯ (цены на стоматологические услуги указаны от)\n\n\n',
#   'analisys_name': 'АКЦИЯ Фотоотбеливание офисное (1 челюсть)',
#   'analisys_cost': '149,25 BYN',
#   'analisys_comment': ''},
#  767: {'source': 'makaenka17med.by',
#   'chapter': 'СТОМАТОЛОГИЯ (цены на стоматологические услуги указаны от)\n\n\n',
#   'analisys_name': 'Стоматологическое обследование при первичном посещении',
#   'analisys_cost': '10,55 BYN',
#   'analisys_comment': ''},
#  768: {'source': 'makaenka17med.by',
#   'chapter': 'СТОМАТОЛОГИЯ (цены на стоматологические услуги указаны от)\n\n\n',
#   'analisys_name': 'Профессиональная гигиена (ультразвуковое снятие зубных отложений, полировка специальными пастами, фтор-лак), цена за 1 зуб',
#   'analisys_cost': '4,50 BYN',
#   'analisys_comment': ''},
#  769: {'source': 'makaenka17med.by',
#   'chapter': 'СТОМАТОЛОГИЯ (цены на стоматологические услуги указаны от)\n\n\n',
#   'analisys_name': 'Лечение неосложненного кариеса зубов',
#   'analisys_cost': '60,00 BYN',
#   'analisys_comment': ''},
#  770: {'source': 'makaenka17med.by',
#   'chapter': 'СТОМАТОЛОГИЯ (цены на стоматологические услуги указаны от)\n\n\n',
#   'analisys_name': 'Лечение эндодонтическое (пульпиты и периодонтиты), за 1 канал без стоимости пломбы',
#   'analisys_cost': '60,00 BYN',
#   'analisys_comment': ''},
#  771: {'source': 'makaenka17med.by',
#   'chapter': 'СТОМАТОЛОГИЯ (цены на стоматологические услуги указаны от)\n\n\n',
#   'analisys_name': 'Лечение эндодонтическое (пульпиты и периодонтиты) инструментами WaveOne Gold, за 1 канал без стоимости пломбы',
#   'analisys_cost': '80,00 BYN',
#   'analisys_comment': ''},
#  772: {'source': 'makaenka17med.by',
#   'chapter': 'СТОМАТОЛОГИЯ (цены на стоматологические услуги указаны от)\n\n\n',
#   'analisys_name': 'Коронка металлокерамическая, дополнительно оплачивается временная конструкция и установление стекловолоконного штифта',
#   'analisys_cost': '220,00 BYN',
#   'analisys_comment': ''},
#  773: {'source': 'makaenka17med.by',
#   'chapter': 'СТОМАТОЛОГИЯ (цены на стоматологические услуги указаны от)\n\n\n',
#   'analisys_name': '\xa0Временная коронка',
#   'analisys_cost': '25,00 BYN',
#   'analisys_comment': ''},
#  774: {'source': 'makaenka17med.by',
#   'chapter': 'СТОМАТОЛОГИЯ (цены на стоматологические услуги указаны от)\n\n\n',
#   'analisys_name': '\xa0Установка стекловолоконного штифта, за 1 зуб',
#   'analisys_cost': '75,00 BYN',
#   'analisys_comment': ''},
#  775: {'source': 'makaenka17med.by',
#   'chapter': 'СТОМАТОЛОГИЯ (цены на стоматологические услуги указаны от)\n\n\n',
#   'analisys_name': 'Коронка безметалловая, коронка на импланте, временная конструкция и установка стекловолоконного штифта оплачивается дополнительно)',
#   'analisys_cost': '500,00 BYN',
#   'analisys_comment': ''},
#  776: {'source': 'makaenka17med.by',
#   'chapter': 'МАНИКЮР И ПЕДИКЮР\n\n\n',
#   'analisys_name': 'Женский маникюр «Классический»',
#   'analisys_cost': '15,00 BYN',
#   'analisys_comment': ''},
#  777: {'source': 'makaenka17med.by',
#   'chapter': 'МАНИКЮР И ПЕДИКЮР\n\n\n',
#   'analisys_name': 'Женский маникюр «Классический» комплекс',
#   'analisys_cost': '20,00 BYN',
#   'analisys_comment': ''},
#  778: {'source': 'makaenka17med.by',
#   'chapter': 'МАНИКЮР И ПЕДИКЮР\n\n\n',
#   'analisys_name': 'Женский маникюр «Классический»+долговременное покрытие',
#   'analisys_cost': '33,00 BYN',
#   'analisys_comment': ''},
#  779: {'source': 'makaenka17med.by',
#   'chapter': 'МАНИКЮР И ПЕДИКЮР\n\n\n',
#   'analisys_name': 'Мужской маникюр',
#   'analisys_cost': '14,00 BYN',
#   'analisys_comment': ''},
#  780: {'source': 'makaenka17med.by',
#   'chapter': 'МАНИКЮР И ПЕДИКЮР\n\n\n',
#   'analisys_name': 'Мужской маникюр комплекс',
#   'analisys_cost': '18,00 BYN',
#   'analisys_comment': ''},
#  781: {'source': 'makaenka17med.by',
#   'chapter': 'МАНИКЮР И ПЕДИКЮР\n\n\n',
#   'analisys_name': 'Снятие долговременного покрытия',
#   'analisys_cost': '6,00 BYN',
#   'analisys_comment': ''},
#  782: {'source': 'makaenka17med.by',
#   'chapter': 'МАНИКЮР И ПЕДИКЮР\n\n\n',
#   'analisys_name': 'Женский педикюр «Классический» комплекс',
#   'analisys_cost': '45,00 BYN',
#   'analisys_comment': ''},
#  783: {'source': 'makaenka17med.by',
#   'chapter': 'МАНИКЮР И ПЕДИКЮР\n\n\n',
#   'analisys_name': 'Женский педикюр «Классический»+долговременное покрытие',
#   'analisys_cost': '55,00 BYN',
#   'analisys_comment': ''},
#  784: {'source': 'makaenka17med.by',
#   'chapter': 'МАНИКЮР И ПЕДИКЮР\n\n\n',
#   'analisys_name': 'Мужской педикюр',
#   'analisys_cost': '35,00 BYN',
#   'analisys_comment': ''},
#  785: {'source': 'makaenka17med.by',
#   'chapter': 'МАНИКЮР И ПЕДИКЮР\n\n\n',
#   'analisys_name': 'Долговременное покрытие',
#   'analisys_cost': '17,00 BYN',
#   'analisys_comment': ''},
#  786: {'source': 'makaenka17med.by',
#   'chapter': 'МАНИКЮР И ПЕДИКЮР\n\n\n',
#   'analisys_name': 'Роспись одного ногтя',
#   'analisys_cost': '1,20 BYN',
#   'analisys_comment': ''}}

# %%
df_maka = pd.DataFrame.from_dict(dict_maka.values())
df_maka
# Out:
#                source                           chapter  \
# 0    makaenka17med.by  КОНСУЛЬТАЦИИ СПЕЦИАЛИСТОВ \n\n\n
# 1    makaenka17med.by  КОНСУЛЬТАЦИИ СПЕЦИАЛИСТОВ \n\n\n
# 2    makaenka17med.by  КОНСУЛЬТАЦИИ СПЕЦИАЛИСТОВ \n\n\n
# 3    makaenka17med.by  КОНСУЛЬТАЦИИ СПЕЦИАЛИСТОВ \n\n\n
# 4    makaenka17med.by  КОНСУЛЬТАЦИИ СПЕЦИАЛИСТОВ \n\n\n
# ..                ...                               ...
# 782  makaenka17med.by           МАНИКЮР И ПЕДИКЮР\n\n\n
# 783  makaenka17med.by           МАНИКЮР И ПЕДИКЮР\n\n\n
# 784  makaenka17med.by           МАНИКЮР И ПЕДИКЮР\n\n\n
# 785  makaenka17med.by           МАНИКЮР И ПЕДИКЮР\n\n\n
# 786  makaenka17med.by           МАНИКЮР И ПЕДИКЮР\n\n\n
#
#                                          analisys_name analisys_cost  \
# 0    Консультация врача-специалиста второй категори...     30,33 BYN
# 1    Консультация врача-специалиста первой категори...     31,13 BYN
# 2    Консультация врача-специалиста высшей категори...     32,24 BYN
# 3    Консультация врача-специалиста КМН терапевтиче...     48,24 BYN
# 4    Консультация врача-специалиста ДМН терапевтиче...     48,88 BYN
# ..                                                 ...           ...
# 782            Женский педикюр «Классический» комплекс     45,00 BYN
# 783  Женский педикюр «Классический»+долговременное ...     55,00 BYN
# 784                                    Мужской педикюр     35,00 BYN
# 785                            Долговременное покрытие     17,00 BYN
# 786                               Роспись одного ногтя      1,20 BYN
#
#             analisys_comment
# 0    Консультация первичная:
# 1    Консультация первичная:
# 2    Консультация первичная:
# 3    Консультация первичная:
# 4    Консультация первичная:
# ..                       ...
# 782
# 783
# 784
# 785
# 786
#
# [787 rows x 5 columns]

# %%
dkvd = DriverKVD()

# %%
dict_kvd = dkvd.get_analisys()
dict_kvd
# Out:
# {0: {'source': 'kvd.by',
#   'chapter': 'Дерматовенерология',
#   'analisys_name': 'АППАРАТНОЕ УДАЛЕНИЕ НОГТЕЙ',
#   'analisys_cost': '\xa0',
#   'analisys_comment': ''},
#  1: {'source': 'kvd.by',
#   'chapter': 'Дерматовенерология',
#   'analisys_name': 'Аппаратное удаление пораженной ногтевой пластинки большого пальца стопы или кисти.',
#   'analisys_cost': '12,24',
#   'analisys_comment': ''},
#  2: {'source': 'kvd.by',
#   'chapter': 'Дерматовенерология',
#   'analisys_name': 'Аппаратное удаление одной пораженной ногтевой пластинки стопы или кисти.',
#   'analisys_cost': '6,78',
#   'analisys_comment': ''},
#  3: {'source': 'kvd.by',
#   'chapter': 'Дерматовенерология',
#   'analisys_name': 'Механическое удаление пораженных частей ногтевой пластинки пальца стопы (кисти)при онихомикозе.',
#   'analisys_cost': '6,38',
#   'analisys_comment': ''},
#  4: {'source': 'kvd.by',
#   'chapter': 'Дерматовенерология',
#   'analisys_name': 'Комплект на 1 человека',
#   'analisys_cost': '1,48',
#   'analisys_comment': ''},
#  5: {'source': 'kvd.by',
#   'chapter': 'Дерматовенерология',
#   'analisys_name': 'Одноразовый комплект для пациента (по желанию пациента дополнительно)',
#   'analisys_cost': '1,96',
#   'analisys_comment': ''},
#  6: {'source': 'kvd.by',
#   'chapter': 'Определение ДНК возбудителей методом ПЦР',
#   'analisys_name': 'Прием и регистрация проб',
#   'analisys_cost': '0,62',
#   'analisys_comment': ''},
#  7: {'source': 'kvd.by',
#   'chapter': 'Определение ДНК возбудителей методом ПЦР',
#   'analisys_name': 'Приём, регистрация и сортировка проб в централизованных лабораториях',
#   'analisys_cost': '1,22',
#   'analisys_comment': ''},
#  8: {'source': 'kvd.by',
#   'chapter': 'Определение ДНК возбудителей методом ПЦР',
#   'analisys_name': 'Взятие биологического материала с помощью транспортных сред и тампонов',
#   'analisys_cost': '0,88',
#   'analisys_comment': ''},
#  9: {'source': 'kvd.by',
#   'chapter': 'Определение ДНК возбудителей методом ПЦР',
#   'analisys_name': 'Первичная обработка биологического материала',
#   'analisys_cost': '6,61',
#   'analisys_comment': ''},
#  10: {'source': 'kvd.by',
#   'chapter': 'Определение ДНК возбудителей методом ПЦР',
#   'analisys_name': 'Первичная обработка биологического материала',
#   'analisys_cost': '6,48',
#   'analisys_comment': ''},
#  11: {'source': 'kvd.by',
#   'chapter': 'Определение ДНК возбудителей методом ПЦР',
#   'analisys_name': 'Первичная обработка биологического материала (транспортная среда)',
#   'analisys_cost': '6,52',
#   'analisys_comment': ''},
#  12: {'source': 'kvd.by',
#   'chapter': 'Определение ДНК возбудителей методом ПЦР',
#   'analisys_name': 'Выделение ДНК из иного биологического материала ручным способом сорбентный метод',
#   'analisys_cost': '7,19',
#   'analisys_comment': ''},
#  13: {'source': 'kvd.by',
#   'chapter': 'Определение ДНК возбудителей методом ПЦР',
#   'analisys_name': 'Выделение ДНК из иного биологическогоматериала ручным способом сорбентный метод (Реал-Бест ДНК-экстракция)',
#   'analisys_cost': '7,09',
#   'analisys_comment': ''},
#  14: {'source': 'kvd.by',
#   'chapter': 'Определение ДНК возбудителей методом ПЦР',
#   'analisys_name': 'Выделение РНК из иного биологического материала (назофарингеальные мазки)',
#   'analisys_cost': '6,17',
#   'analisys_comment': ''},
#  15: {'source': 'kvd.by',
#   'chapter': 'Определение ДНК возбудителей методом ПЦР',
#   'analisys_name': 'Выявления Сhlamydia trachomatis методом ПЦР качественное определение',
#   'analisys_cost': '17,15',
#   'analisys_comment': ''},
#  16: {'source': 'kvd.by',
#   'chapter': 'Определение ДНК возбудителей методом ПЦР',
#   'analisys_name': 'Выявления HSV I,II -вирус простого герпеса методом ПЦР качественное определение',
#   'analisys_cost': '16,4',
#   'analisys_comment': ''},
#  17: {'source': 'kvd.by',
#   'chapter': 'Определение ДНК возбудителей методом ПЦР',
#   'analisys_name': 'Выявления HPV - вирус папилломы человека методом ПЦР качественное определение',
#   'analisys_cost': '31,4',
#   'analisys_comment': ''},
#  18: {'source': 'kvd.by',
#   'chapter': 'Определение ДНК возбудителей методом ПЦР',
#   'analisys_name': 'Выявления Тrichomonas vaginalis методом ПЦР качественное определение',
#   'analisys_cost': '16,92',
#   'analisys_comment': ''},
#  19: {'source': 'kvd.by',
#   'chapter': 'Определение ДНК возбудителей методом ПЦР',
#   'analisys_name': 'Выявления Mycoplasma genitalium методом ПЦР качественное определение',
#   'analisys_cost': '17,38',
#   'analisys_comment': ''},
#  20: {'source': 'kvd.by',
#   'chapter': 'Определение ДНК возбудителей методом ПЦР',
#   'analisys_name': 'Выявления Neisseria gonorrhoeae методом ПЦР качественное определение',
#   'analisys_cost': '16,52',
#   'analisys_comment': ''},
#  21: {'source': 'kvd.by',
#   'chapter': 'Определение ДНК возбудителей методом ПЦР',
#   'analisys_name': 'Выявления Ureaplasma urealyticum методом ПЦР качественное определение',
#   'analisys_cost': '16,81',
#   'analisys_comment': ''},
#  22: {'source': 'kvd.by',
#   'chapter': 'Определение ДНК возбудителей методом ПЦР',
#   'analisys_name': 'Выявление инфекционных возбудителей "ФЕМОФЛОР-СКРИН" (1.2 +9.1.2. +9.3.1.2.4 +9.4.2.1)',
#   'analisys_cost': '84,53',
#   'analisys_comment': ''},
#  23: {'source': 'kvd.by',
#   'chapter': 'Определение ДНК возбудителей методом ПЦР',
#   'analisys_name': 'Выявления HPV - вирус папилломы человека методом ПЦР КОЛИЧЕСТВЕННОЕ определение',
#   'analisys_cost': '42,61',
#   'analisys_comment': ''},
#  24: {'source': 'kvd.by',
#   'chapter': 'Определение ДНК возбудителей методом ПЦР',
#   'analisys_name': 'Выявление РНК инфекции COVID-19 методом ПЦР',
#   'analisys_cost': '16,19',
#   'analisys_comment': ''},
#  25: {'source': 'kvd.by',
#   'chapter': 'Определение ДНК возбудителей методом ПЦР',
#   'analisys_name': 'Тестирование с QR-кодом через информационную систему " Путешествую без COVID-19"',
#   'analisys_cost': '9,56',
#   'analisys_comment': ''},
#  26: {'source': 'kvd.by',
#   'chapter': 'Определение ДНК возбудителей методом ПЦР',
#   'analisys_name': 'Оформление документов для выезда за рубеж',
#   'analisys_cost': '5,92',
#   'analisys_comment': ''},
#  27: {'source': 'kvd.by',
#   'chapter': 'Гистология',
#   'analisys_name': 'Взятие материала для исследования биопсии',
#   'analisys_cost': '39,33',
#   'analisys_comment': ''},
#  28: {'source': 'kvd.by',
#   'chapter': 'Гистология',
#   'analisys_name': 'Гистологическое исследование операционногого, биопсийного и секционного материала',
#   'analisys_cost': '10,52',
#   'analisys_comment': ''},
#  29: {'source': 'kvd.by',
#   'chapter': 'Гистология',
#   'analisys_name': 'Консультация готовых гистологических микропрепаратов',
#   'analisys_cost': '6,83',
#   'analisys_comment': ''},
#  30: {'source': 'kvd.by',
#   'chapter': 'Гистология',
#   'analisys_name': 'Материалы для биопсии новообразований (косметология)',
#   'analisys_cost': '0,13',
#   'analisys_comment': ''},
#  31: {'source': 'kvd.by',
#   'chapter': 'Анонимное обследование на инфекции, передаваемые половым путем (мужское)',
#   'analisys_name': 'Первичный прием больных с ИППП',
#   'analisys_cost': '13,39',
#   'analisys_comment': ''},
#  32: {'source': 'kvd.by',
#   'chapter': 'Анонимное обследование на инфекции, передаваемые половым путем (мужское)',
#   'analisys_name': 'Повторный\xa0 прием больных с ИППП',
#   'analisys_cost': '10,56',
#   'analisys_comment': ''},
#  33: {'source': 'kvd.by',
#   'chapter': 'Анонимное обследование на инфекции, передаваемые половым путем (мужское)',
#   'analisys_name': 'Бак.пос. М. Культуральное исследование отделяемого мочеполовых органов на гонококковую инфекцию при отсутствии микроорганизмов',
#   'analisys_cost': '20,95',
#   'analisys_comment': ''},
#  34: {'source': 'kvd.by',
#   'chapter': 'Анонимное обследование на инфекции, передаваемые половым путем (мужское)',
#   'analisys_name': 'Бак.пос М\xa0 кон. Культуральное исследование отделяемого мочеполовых органов на гонококковую инфекцию с идентификацией до вида классическим методом',
#   'analisys_cost': '39,82',
#   'analisys_comment': ''},
#  35: {'source': 'kvd.by',
#   'chapter': 'Анонимное обследование на инфекции, передаваемые половым путем (мужское)',
#   'analisys_name': 'М. Микроскопич-кое исслед. отделя-го мочепол. органов метиленовым синим',
#   'analisys_cost': '6,92',
#   'analisys_comment': ''},
#  36: {'source': 'kvd.by',
#   'chapter': 'Анонимное обследование на инфекции, передаваемые половым путем (мужское)',
#   'analisys_name': 'М. Микроскопическое исслед. отделя-го мочепол. органов\xa0\xa0 по Грамму',
#   'analisys_cost': '7,87',
#   'analisys_comment': ''},
#  37: {'source': 'kvd.by',
#   'chapter': 'Анонимное обследование на инфекции, передаваемые половым путем (мужское)',
#   'analisys_name': 'Микоплазма IES мужской\xa0',
#   'analisys_cost': '26,56',
#   'analisys_comment': ''},
#  38: {'source': 'kvd.by',
#   'chapter': 'Анонимное обследование на инфекции, передаваемые половым путем (мужское)',
#   'analisys_name': 'Чувствительность\xa0 к антибиот. автоматиз. сис. мужской\xa0',
#   'analisys_cost': '93,87',
#   'analisys_comment': ''},
#  39: {'source': 'kvd.by',
#   'chapter': 'Анонимное обследование на инфекции, передаваемые половым путем (мужское)',
#   'analisys_name': 'Чувствительность к антибиот. ручным методом. мужской\xa0',
#   'analisys_cost': '41,68',
#   'analisys_comment': ''},
#  40: {'source': 'kvd.by',
#   'chapter': 'Анонимное обследование на инфекции, передаваемые половым путем (мужское)',
#   'analisys_name': 'Комплект 1 мужской',
#   'analisys_cost': '0,99',
#   'analisys_comment': ''},
#  41: {'source': 'kvd.by',
#   'chapter': 'Анонимное обследование на инфекции, передаваемые половым путем (мужское)',
#   'analisys_name': 'Комплект 2 мужской',
#   'analisys_cost': '1,2',
#   'analisys_comment': ''},
#  42: {'source': 'kvd.by',
#   'chapter': 'Анонимное обследование на инфекции, передаваемые половым путем (мужское)',
#   'analisys_name': 'Взятие материала для исследования методом ПЦР (мужское)',
#   'analisys_cost': '3,44',
#   'analisys_comment': ''},
#  43: {'source': 'kvd.by',
#   'chapter': 'Анонимное обследование на инфекции, передаваемые половым путем (мужское)',
#   'analisys_name': '\xa0\xa0\xa0\xa0\xa0 Прием и регистрация проб',
#   'analisys_cost': '0,62',
#   'analisys_comment': ''},
#  44: {'source': 'kvd.by',
#   'chapter': 'Анонимное обследование на инфекции, передаваемые половым путем (мужское)',
#   'analisys_name': '\xa0\xa0\xa0\xa0\xa0 Первичная обработка биологического материала',
#   'analisys_cost': '6,48',
#   'analisys_comment': ''},
#  45: {'source': 'kvd.by',
#   'chapter': 'Анонимное обследование на инфекции, передаваемые половым путем (мужское)',
#   'analisys_name': '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 Выделение ДНК из иного биологического материала ручным способом сорбентный метод',
#   'analisys_cost': '7,18',
#   'analisys_comment': ''},
#  46: {'source': 'kvd.by',
#   'chapter': 'Анонимное обследование на инфекции, передаваемые половым путем (мужское)',
#   'analisys_name': '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 Выявления\xa0 Сhlamydia trachomatis методом ПЦР качественное определение',
#   'analisys_cost': '17,15',
#   'analisys_comment': ''},
#  47: {'source': 'kvd.by',
#   'chapter': 'Анонимное обследование на инфекции, передаваемые половым путем (мужское)',
#   'analisys_name': '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 Выявления\xa0 HSV I,II -вирус простого герпеса методом ПЦР качественное определение',
#   'analisys_cost': '16,40',
#   'analisys_comment': ''},
#  48: {'source': 'kvd.by',
#   'chapter': 'Анонимное обследование на инфекции, передаваемые половым путем (мужское)',
#   'analisys_name': '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 Выявления HPV - вирус папилломы человека методом ПЦР качественное определение',
#   'analisys_cost': '31,40',
#   'analisys_comment': ''},
#  49: {'source': 'kvd.by',
#   'chapter': 'Анонимное обследование на инфекции, передаваемые половым путем (мужское)',
#   'analisys_name': '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 Выявления Тrichomonas vaginalis методом ПЦР качественное определение',
#   'analisys_cost': '16,92',
#   'analisys_comment': ''},
#  50: {'source': 'kvd.by',
#   'chapter': 'Анонимное обследование на инфекции, передаваемые половым путем (мужское)',
#   'analisys_name': '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 Выявления Mycoplasma genitalium методом\xa0 ПЦР качественное определение',
#   'analisys_cost': '17,38',
#   'analisys_comment': ''},
#  51: {'source': 'kvd.by',
#   'chapter': 'Анонимное обследование на инфекции, передаваемые половым путем (мужское)',
#   'analisys_name': '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 Выявления Neisseria gonorrhoeae методом ПЦР качественное определение',
#   'analisys_cost': '16,52',
#   'analisys_comment': ''},
#  52: {'source': 'kvd.by',
#   'chapter': 'Анонимное обследование на инфекции, передаваемые половым путем (мужское)',
#   'analisys_name': '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 Выявления Ureaplasma urealyticum методом ПЦР качественное определение',
#   'analisys_cost': '16,81',
#   'analisys_comment': ''},
#  53: {'source': 'kvd.by',
#   'chapter': 'Анонимное обследование на инфекции, передаваемые половым путем (мужское)',
#   'analisys_name': '\xa0\xa0\xa0\xa0\xa0\xa0\xa0 Выявления HPV - вирус папилломы человека методом ПЦР КОЛИЧЕСТВЕННОЕ определение',
#   'analisys_cost': '42,91',
#   'analisys_comment': ''},
#  54: {'source': 'kvd.by',
#   'chapter': 'Анонимное обследование на инфекции, передаваемые половым путем (мужское)',
#   'analisys_name': 'Ложка фолькмана одноразовая',
#   'analisys_cost': '0,28',
#   'analisys_comment': ''},
#  55: {'source': 'kvd.by',
#   'chapter': 'Анонимное обследование на инфекции, передаваемые половым путем (мужское)',
#   'analisys_name': 'Петля одноразовая',
#   'analisys_cost': '0,11',
#   'analisys_comment': ''},
#  56: {'source': 'kvd.by',
#   'chapter': 'Анонимное обследование на инфекции, передаваемые половым путем (мужское)',
#   'analisys_name': 'Зонд урогенетальный одноразовый',
#   'analisys_cost': '0,49',
#   'analisys_comment': ''},
#  57: {'source': 'kvd.by',
#   'chapter': 'Анонимное обследование на инфекции, передаваемые половым путем (мужское)',
#   'analisys_name': 'Пробирка с крышкой 16*100мм',
#   'analisys_cost': '0,24',
#   'analisys_comment': ''},
#  58: {'source': 'kvd.by',
#   'chapter': 'Анонимное обследование на инфекции, передаваемые половым путем (мужское)',
#   'analisys_name': 'Комплекс 3',
#   'analisys_cost': '1,17',
#   'analisys_comment': ''},
#  59: {'source': 'kvd.by',
#   'chapter': 'Анонимное обследование на инфекции, передаваемые половым путем (мужское)',
#   'analisys_name': 'Забор крови (с комплектом № 3)',
#   'analisys_cost': '2,00',
#   'analisys_comment': ''},
#  60: {'source': 'kvd.by',
#   'chapter': 'Анонимное обследование на инфекции, передаваемые половым путем (женское)',
#   'analisys_name': 'Первичный прием больных с ИППП',
#   'analisys_cost': '16,25',
#   'analisys_comment': ''},
#  61: {'source': 'kvd.by',
#   'chapter': 'Анонимное обследование на инфекции, передаваемые половым путем (женское)',
#   'analisys_name': 'Повторный прием больных с ИППП',
#   'analisys_cost': '13,39',
#   'analisys_comment': ''},
#  62: {'source': 'kvd.by',
#   'chapter': 'Анонимное обследование на инфекции, передаваемые половым путем (женское)',
#   'analisys_name': 'Бак пос. ж Культурал.иссл. отдел.мочепол оргонов на гоноковую инфекцию при отсутствии микроорганизмив\xa0',
#   'analisys_cost': '39,72',
#   'analisys_comment': ''},
#  63: {'source': 'kvd.by',
#   'chapter': 'Анонимное обследование на инфекции, передаваемые половым путем (женское)',
#   'analisys_name': 'Бак пос. ж конт. Культуральное исследование отделяемого мочеполовых органов на гонококковую инфекцию с идентификацией до вида классическим методом\xa0',
#   'analisys_cost': '48,86',
#   'analisys_comment': ''},
#  64: {'source': 'kvd.by',
#   'chapter': 'Анонимное обследование на инфекции, передаваемые половым путем (женское)',
#   'analisys_name': 'Ж.Микроскопи-ое исслед. отделя-го мочепол.органов\xa0 метиленовым синим',
#   'analisys_cost': '11,88',
#   'analisys_comment': ''},
#  65: {'source': 'kvd.by',
#   'chapter': 'Анонимное обследование на инфекции, передаваемые половым путем (женское)',
#   'analisys_name': 'Ж.Микроскопиче-кое исслед. отделя-го мочепол. органов\xa0\xa0 по Грамму',
#   'analisys_cost': '13,78',
#   'analisys_comment': ''},
#  66: {'source': 'kvd.by',
#   'chapter': 'Анонимное обследование на инфекции, передаваемые половым путем (женское)',
#   'analisys_name': 'Микоплазма IЕS женская\xa0',
#   'analisys_cost': '27,38',
#   'analisys_comment': ''},
#  67: {'source': 'kvd.by',
#   'chapter': 'Анонимное обследование на инфекции, передаваемые половым путем (женское)',
#   'analisys_name': 'Скрининговое исследование (Фемофлер)\xa0',
#   'analisys_cost': '90,89',
#   'analisys_comment': ''},
#  68: {'source': 'kvd.by',
#   'chapter': 'Анонимное обследование на инфекции, передаваемые половым путем (женское)',
#   'analisys_name': 'Чувствительность к антибиот. автом.сист.женская\xa0',
#   'analisys_cost': '95,13',
#   'analisys_comment': ''},
#  69: {'source': 'kvd.by',
#   'chapter': 'Анонимное обследование на инфекции, передаваемые половым путем (женское)',
#   'analisys_name': 'Чувствительность к антибиот. ручной метод женская\xa0\xa0',
#   'analisys_cost': '42,94',
#   'analisys_comment': ''},
#  70: {'source': 'kvd.by',
#   'chapter': 'Анонимное обследование на инфекции, передаваемые половым путем (женское)',
#   'analisys_name': 'ИФА(с комплектом №3)\xa0',
#   'analisys_cost': '7,19',
#   'analisys_comment': ''},
#  71: {'source': 'kvd.by',
#   'chapter': 'Анонимное обследование на инфекции, передаваемые половым путем (женское)',
#   'analisys_name': 'Комплект 1 женский',
#   'analisys_cost': '2,08',
#   'analisys_comment': ''},
#  72: {'source': 'kvd.by',
#   'chapter': 'Анонимное обследование на инфекции, передаваемые половым путем (женское)',
#   'analisys_name': 'Комплект 2 женский\xa0',
#   'analisys_cost': '2,28',
#   'analisys_comment': ''},
#  73: {'source': 'kvd.by',
#   'chapter': 'Анонимное обследование на инфекции, передаваемые половым путем (женское)',
#   'analisys_name': 'Взятие материала\xa0 из уретры для исследования методом ПЦР (женское)',
#   'analisys_cost': '5,16',
#   'analisys_comment': ''},
#  74: {'source': 'kvd.by',
#   'chapter': 'Анонимное обследование на инфекции, передаваемые половым путем (женское)',
#   'analisys_name': '\xa0\xa0\xa0\xa0\xa0 Прием и регистрация проб',
#   'analisys_cost': '0,62',
#   'analisys_comment': ''},
#  75: {'source': 'kvd.by',
#   'chapter': 'Анонимное обследование на инфекции, передаваемые половым путем (женское)',
#   'analisys_name': '\xa0\xa0\xa0\xa0\xa0 Первичная обработка биологического материала',
#   'analisys_cost': '6,48',
#   'analisys_comment': ''},
#  76: {'source': 'kvd.by',
#   'chapter': 'Анонимное обследование на инфекции, передаваемые половым путем (женское)',
#   'analisys_name': '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 Выделение ДНК из иного биологического материала ручным способом сорбентный метод',
#   'analisys_cost': '7,18',
#   'analisys_comment': ''},
#  77: {'source': 'kvd.by',
#   'chapter': 'Анонимное обследование на инфекции, передаваемые половым путем (женское)',
#   'analisys_name': '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 Выявления\xa0 Сhlamydia trachomatis методом ПЦР качественное определение',
#   'analisys_cost': '17,15',
#   'analisys_comment': ''},
#  78: {'source': 'kvd.by',
#   'chapter': 'Анонимное обследование на инфекции, передаваемые половым путем (женское)',
#   'analisys_name': '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 Выявления\xa0 HSV I,II -вирус простого герпеса методом ПЦР качественное определение',
#   'analisys_cost': '16,40',
#   'analisys_comment': ''},
#  79: {'source': 'kvd.by',
#   'chapter': 'Анонимное обследование на инфекции, передаваемые половым путем (женское)',
#   'analisys_name': '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 Выявления HPV - вирус папилломы человека методом ПЦР качественное определение',
#   'analisys_cost': '31,40',
#   'analisys_comment': ''},
#  80: {'source': 'kvd.by',
#   'chapter': 'Анонимное обследование на инфекции, передаваемые половым путем (женское)',
#   'analisys_name': '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 Выявления Тrichomonas vaginalis методом ПЦР качественное определение',
#   'analisys_cost': '16,92',
#   'analisys_comment': ''},
#  81: {'source': 'kvd.by',
#   'chapter': 'Анонимное обследование на инфекции, передаваемые половым путем (женское)',
#   'analisys_name': '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 Выявления Mycoplasma genitalium методом\xa0 ПЦР качественное определение',
#   'analisys_cost': '17,38',
#   'analisys_comment': ''},
#  82: {'source': 'kvd.by',
#   'chapter': 'Анонимное обследование на инфекции, передаваемые половым путем (женское)',
#   'analisys_name': '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 Выявления Neisseria gonorrhoeae методом ПЦР качественное определение',
#   'analisys_cost': '16,52',
#   'analisys_comment': ''},
#  83: {'source': 'kvd.by',
#   'chapter': 'Анонимное обследование на инфекции, передаваемые половым путем (женское)',
#   'analisys_name': '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 Выявления Ureaplasma urealyticum методом ПЦР качественное определение',
#   'analisys_cost': '16,81',
#   'analisys_comment': ''},
#  84: {'source': 'kvd.by',
#   'chapter': 'Анонимное обследование на инфекции, передаваемые половым путем (женское)',
#   'analisys_name': '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 Выявление инфекционных возбудителей "ФЕМОФЛОР-СКРИН" (1.2+9.1.2.+9.3.1.2.4+9.4.2.1)',
#   'analisys_cost': '85,73',
#   'analisys_comment': ''},
#  85: {'source': 'kvd.by',
#   'chapter': 'Анонимное обследование на инфекции, передаваемые половым путем (женское)',
#   'analisys_name': '\xa0\xa0\xa0\xa0\xa0\xa0\xa0 Выявления HPV - вирус папилломы человека методом ПЦР КОЛИЧЕСТВЕННОЕ определение',
#   'analisys_cost': '42,91',
#   'analisys_comment': ''},
#  86: {'source': 'kvd.by',
#   'chapter': 'Анонимное обследование на инфекции, передаваемые половым путем (женское)',
#   'analisys_name': 'Ложка фолькмана одноразовая',
#   'analisys_cost': '0,28',
#   'analisys_comment': ''},
#  87: {'source': 'kvd.by',
#   'chapter': 'Анонимное обследование на инфекции, передаваемые половым путем (женское)',
#   'analisys_name': 'Петля одноразовая',
#   'analisys_cost': '0,11',
#   'analisys_comment': ''},
#  88: {'source': 'kvd.by',
#   'chapter': 'Анонимное обследование на инфекции, передаваемые половым путем (женское)',
#   'analisys_name': 'Зонд урогенетальный одноразовый',
#   'analisys_cost': '0,49',
#   'analisys_comment': ''},
#  89: {'source': 'kvd.by',
#   'chapter': 'Анонимное обследование на инфекции, передаваемые половым путем (женское)',
#   'analisys_name': 'Пробирка с крышкой 16*100мм',
#   'analisys_cost': '0,24',
#   'analisys_comment': ''},
#  90: {'source': 'kvd.by',
#   'chapter': 'Анонимное обследование на инфекции, передаваемые половым путем (женское)',
#   'analisys_name': 'Комплекс 3',
#   'analisys_cost': '1,17',
#   'analisys_comment': ''},
#  91: {'source': 'kvd.by',
#   'chapter': 'Анонимное обследование на инфекции, передаваемые половым путем (женское)',
#   'analisys_name': 'Забор крови (с комплектом № 3)',
#   'analisys_cost': '2,00',
#   'analisys_comment': ''},
#  92: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Паровая ванна лица',
#   'analisys_cost': '6,77',
#   'analisys_comment': ''},
#  93: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Противокуперозная маска для профилактики и лечения возрастной атрофии кожи лица',
#   'analisys_cost': '16,51',
#   'analisys_comment': ''},
#  94: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Противокуперозная маска для профилактики и лечения возрастной атрофии кожи шеи',
#   'analisys_cost': '16,51',
#   'analisys_comment': ''},
#  95: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Противокуперозная маска для профилактики и лечения возрастной атрофии кожи передней поверхности грудной клетки',
#   'analisys_cost': '16,51',
#   'analisys_comment': ''},
#  96: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Маска для профилактики и лечения воспалительных заболеваний кожи лица',
#   'analisys_cost': '12,86',
#   'analisys_comment': ''},
#  97: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Маска для профилактики и лечения воспалительных заболеваний кожи шеи',
#   'analisys_cost': '12,98',
#   'analisys_comment': ''},
#  98: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Маска для профилактики и лечения воспалительных заболеваний кожи передней поверхности грудной клетки',
#   'analisys_cost': '12,89',
#   'analisys_comment': ''},
#  99: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Маска для профилактики и лечения воспалительных заболеваний кожи задней поверхности грудной клетки',
#   'analisys_cost': '12,98',
#   'analisys_comment': ''},
#  100: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Массаж лечебный (по Жаке)',
#   'analisys_cost': '6,57',
#   'analisys_comment': ''},
#  101: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Криомассаж кожи лица жидким азотом',
#   'analisys_cost': '4',
#   'analisys_comment': ''},
#  102: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Очищение кожи лица механическое',
#   'analisys_cost': '14,02',
#   'analisys_comment': ''},
#  103: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Поверхностный механический пилинг лица',
#   'analisys_cost': '25,59',
#   'analisys_comment': ''},
#  104: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Дарсонвализация лица местная',
#   'analisys_cost': '5,79',
#   'analisys_comment': ''},
#  105: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Поверхностный химический пилинг САЛИЦИЛИКПИЛ JS',
#   'analisys_cost': '46,14',
#   'analisys_comment': ''},
#  106: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Поверхностный химический пилинг лицама Салициликпил 25% с пантенолом',
#   'analisys_cost': '43,26',
#   'analisys_comment': ''},
#  107: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Поверхностный химический пилинг Миндальный 40%',
#   'analisys_cost': '72,11',
#   'analisys_comment': ''},
#  108: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Поверхностный химический пилинг BLOCK ADE PEEL',
#   'analisys_cost': '65,81',
#   'analisys_comment': ''},
#  109: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Химический пилинг среднего уровня с пантенолом',
#   'analisys_cost': '84,23',
#   'analisys_comment': ''},
#  110: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Мезотерапия кожи (1 анатомическая область) без препарата',
#   'analisys_cost': '53,19',
#   'analisys_comment': ''},
#  111: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Биоревитализация без препарата',
#   'analisys_cost': '94,37',
#   'analisys_comment': ''},
#  112: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Проба на реакцию при введении препарата "Коллост"',
#   'analisys_cost': '11,21',
#   'analisys_comment': ''},
#  113: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Инъекционная контурная коррекция средней трети лица при возрастной атрофии кожи',
#   'analisys_cost': '212,17',
#   'analisys_comment': ''},
#  114: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Инъекционная контурная коррекция статических морщин при возрастной атрофии кожи лобной области',
#   'analisys_cost': '123,84',
#   'analisys_comment': ''},
#  115: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Инъекционная контурная коррекция статических морщин при возрастной атрофии кожи носо-губных складок',
#   'analisys_cost': '123,84',
#   'analisys_comment': ''},
#  116: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Инъекционная контурная коррекция статических морщин при возрастной атрофии кожи верхней губы',
#   'analisys_cost': '123,84',
#   'analisys_comment': ''},
#  117: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Инъекционная контурная коррекция статических морщин при возрастной атрофии кожи нижней губы',
#   'analisys_cost': '123,84',
#   'analisys_comment': ''},
#  118: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Аппликационная анестезия (крем) за 2кв.см.',
#   'analisys_cost': '3,61',
#   'analisys_comment': ''},
#  119: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Аппликационная анестезия (спрей)',
#   'analisys_cost': '4,09',
#   'analisys_comment': ''},
#  120: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Инфильтрационная анестезия',
#   'analisys_cost': '3,91',
#   'analisys_comment': ''},
#  121: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Криодеструкция 1 элемента доброкачественного новообразования кожи вирусной этиологии (бородавка, папиллома, контагиозный моллюск, кондилома)',
#   'analisys_cost': '2,02',
#   'analisys_comment': ''},
#  122: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Криотерапия при воспалительных заболеваниях кожи',
#   'analisys_cost': '4,7',
#   'analisys_comment': ''},
#  123: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Криодеструкция доброкачествен. новообразований кожи и красной каймы губ до 0,5 см',
#   'analisys_cost': '4,54',
#   'analisys_comment': ''},
#  124: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Криодеструкция доброкачествен. новообразований кожи и красной каймы губ от 0,5 см до 1 см',
#   'analisys_cost': '6,13',
#   'analisys_comment': ''},
#  125: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Криодеструкция телеангиоэктазий, участков гиперпигментации, гиперкератоза за 1 кв. см',
#   'analisys_cost': '3,86',
#   'analisys_comment': ''},
#  126: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Криодеструкция рубцов за 1 см',
#   'analisys_cost': '6,42',
#   'analisys_comment': ''},
#  127: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Механическое удаление контагиозного моллюска (1-го элемента)',
#   'analisys_cost': '4,34',
#   'analisys_comment': ''},
#  128: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Электро-радиокоагуляция 1 элемента доброкачествен. новообразования кожи вирусной этиологии (бородавка, папиллома, контагиозный моллюск, кондилома)',
#   'analisys_cost': '6,42',
#   'analisys_comment': ''},
#  129: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Электро-радиокоагуляция доброкачествен. новообразований кожи до 0,5 см',
#   'analisys_cost': '7,75',
#   'analisys_comment': ''},
#  130: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Электро-радиокоагуляция доброкачественных сосудистых новообразований кожи и красной каймы губ за 1 кв. см',
#   'analisys_cost': '11,76',
#   'analisys_comment': ''},
#  131: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Электрокоагуляция доброкачествен. новообразований кожи и красной каймы губ от 0,5 см до 1 см',
#   'analisys_cost': '14,69',
#   'analisys_comment': ''},
#  132: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Электро-радиокоагуляция телеангиоэктазий, участков гиперпигментации, гиперкератоза за 1 кв. см',
#   'analisys_cost': '11,02',
#   'analisys_comment': ''},
#  133: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Электро-радиокоагуляция воспалительного инфильтрата кожи за 1 элемент (угри, нагноившиеся кисты сальных желез)',
#   'analisys_cost': '6,24',
#   'analisys_comment': ''},
#  134: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Электро-радиокоагуляция невусов за 1 мм',
#   'analisys_cost': '6,24',
#   'analisys_comment': ''},
#  135: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Электро-радиокоагуляция гипертрофических рубцов после перенесенных воспалительных заболеваний кожи за 1 см',
#   'analisys_cost': '10,96',
#   'analisys_comment': ''},
#  136: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Устранение пигментной импрегнации (татуировки) кожи методом электро-радиокоагуляции за 1 кв. см',
#   'analisys_cost': '19,85',
#   'analisys_comment': ''},
#  137: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Коррекция функциональных морщин препаратом на основе ботулотоксина лобной области',
#   'analisys_cost': '259,62',
#   'analisys_comment': ''},
#  138: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Коррекция функциональных морщин препаратом на основе ботулотоксина (нейронокс) лобной области',
#   'analisys_cost': '204,45',
#   'analisys_comment': ''},
#  139: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Коррекция функциональных морщин препаратом на основе ботулотоксина области переносицы',
#   'analisys_cost': '259,62',
#   'analisys_comment': ''},
#  140: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Коррекция функциональных морщин препаратом на основе ботулотоксина (нейронокс) области переносицы',
#   'analisys_cost': '204,45',
#   'analisys_comment': ''},
#  141: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Коррекция функциональных морщин препаратом на основе ботулотоксина периорбитальных областей',
#   'analisys_cost': '259,62',
#   'analisys_comment': ''},
#  142: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Коррекция функциональных морщин препаратом на основе ботулотоксина (нейронокс) периорбитальных областей',
#   'analisys_cost': '204,45',
#   'analisys_comment': ''},
#  143: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Коррекция локального гипергидроза препаратом на основе ботулотоксина подмышечных областей',
#   'analisys_cost': '838,77',
#   'analisys_comment': ''},
#  144: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Коррекция локального гипергидроза препаратом на основе ботулотоксина (нейронокс) подмышечных областей',
#   'analisys_cost': '618,19',
#   'analisys_comment': ''},
#  145: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Коррекция локального гипергидроза препаратом на основе ботулотоксина кистей рук',
#   'analisys_cost': '838,88',
#   'analisys_comment': ''},
#  146: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Коррекция локального гипергидроза препаратом на основе ботулотоксина (нейронокс) кистей рук',
#   'analisys_cost': '618,19',
#   'analisys_comment': ''},
#  147: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Коррекция локального гипергидроза препаратом на основе ботулотоксина стоп',
#   'analisys_cost': '838,88',
#   'analisys_comment': ''},
#  148: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Коррекция локального гипергидроза препаратом на основе ботулотоксина (нейронокс) стоп',
#   'analisys_cost': '618,19',
#   'analisys_comment': ''},
#  149: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Фотолечение возрастных изменений кожи лица',
#   'analisys_cost': '130,89',
#   'analisys_comment': ''},
#  150: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Фотолечение возрастных изменений кожи в области щек',
#   'analisys_cost': '76,68',
#   'analisys_comment': ''},
#  151: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Фотолечение возрастных изменений кожи в лобной области',
#   'analisys_cost': '76,68',
#   'analisys_comment': ''},
#  152: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Фотолечение возрастных изменений кожи в области носа',
#   'analisys_cost': '41,46',
#   'analisys_comment': ''},
#  153: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Фотолечение возрастных изменений кожи в подбородочной области',
#   'analisys_cost': '41,02',
#   'analisys_comment': ''},
#  154: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Фотолечение возрастных изменений кожи в области верхней губы',
#   'analisys_cost': '41,5',
#   'analisys_comment': ''},
#  155: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Фотолечение возврастных изменений кожи в области шеи',
#   'analisys_cost': '80,91',
#   'analisys_comment': ''},
#  156: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Фотолечение возрастных изменений кожи в области передней поверхности грудной клетки',
#   'analisys_cost': '94,31',
#   'analisys_comment': ''},
#  157: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Фотолечение возрастных изменений кожи тыльной поверхности кистей',
#   'analisys_cost': '76,08',
#   'analisys_comment': ''},
#  158: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Фотолечение угревой болезни.розацеа',
#   'analisys_cost': '105,47',
#   'analisys_comment': ''},
#  159: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Фотоэпиляция в области верхней губы (1 импульс)',
#   'analisys_cost': '5,92',
#   'analisys_comment': ''},
#  160: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Фотоэпиляция в подбородочной области (1 импульс)',
#   'analisys_cost': '4,33',
#   'analisys_comment': ''},
#  161: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Фотоэпиляция в области шеи, на щеках (1 импульс)',
#   'analisys_cost': '3,21',
#   'analisys_comment': ''},
#  162: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Фотоэпиляция в области конечностей (1 импульс)',
#   'analisys_cost': '1,04',
#   'analisys_comment': ''},
#  163: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Фотоэпиляция в подмышечной области (1 импульс)',
#   'analisys_cost': '2,63',
#   'analisys_comment': ''},
#  164: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Фотоэпиляция в области грудной клетки у мужчин (1 импульс)',
#   'analisys_cost': '1,66',
#   'analisys_comment': ''},
#  165: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Фотоэпиляция в области грудной клетки у женщин (1 импульс)',
#   'analisys_cost': '4,73',
#   'analisys_comment': ''},
#  166: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Фотоэпиляция в области паховых складок (1импульс)',
#   'analisys_cost': '2,63',
#   'analisys_comment': ''},
#  167: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Фотоэпиляция в области наружных половых органов (1 импульс)',
#   'analisys_cost': '4,27',
#   'analisys_comment': ''},
#  168: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Фотоэпиляция в ягодичной области (1 импульс)',
#   'analisys_cost': '1,1',
#   'analisys_comment': ''},
#  169: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Фотоэпиляция в пояснично-крестцовой области (1 импульс)',
#   'analisys_cost': '1,43',
#   'analisys_comment': ''},
#  170: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Фотоэпиляция в области промежности (1 импульс)',
#   'analisys_cost': '6,34',
#   'analisys_comment': ''},
#  171: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Фотоэпиляция на коже спины (1 импульс)',
#   'analisys_cost': '1,03',
#   'analisys_comment': ''},
#  172: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Фотоэпиляция на пальцах (1 импульс)',
#   'analisys_cost': '2,05',
#   'analisys_comment': ''},
#  173: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Фотоэпиляция в области живота у женщин (1 импульс)',
#   'analisys_cost': '1,6',
#   'analisys_comment': ''},
#  174: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Фотоэпиляция в области живота у мужчин (1 импульс)',
#   'analisys_cost': '1,21',
#   'analisys_comment': ''},
#  175: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Процедура PRP- терапии',
#   'analisys_cost': '93,48',
#   'analisys_comment': ''},
#  176: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Инъекционная контурная коррекция статических морщин аутологическим тромбинофибриновым гелем (PRP- терапии)',
#   'analisys_cost': '124,29',
#   'analisys_comment': ''},
#  177: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Забор крови для PRP-терапии',
#   'analisys_cost': '1,86',
#   'analisys_comment': ''},
#  178: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': '\n\nДополнительные материалы\n\n',
#   'analisys_cost': '\xa0',
#   'analisys_comment': ''},
#  179: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': '\n\nКомплект для химических пилингов и инъекционных процедур\n\n',
#   'analisys_cost': '1,29',
#   'analisys_comment': ''},
#  180: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': '\n\nКомплект для криодеструкции и электрокоагуляции\n\n',
#   'analisys_cost': '1,75',
#   'analisys_comment': ''},
#  181: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': '\n\nКомплект для демакияжа\n\n',
#   'analisys_cost': '0,23',
#   'analisys_comment': ''},
#  182: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': '\n\nДексаметазон (ампула)\n\n',
#   'analisys_cost': '0,47',
#   'analisys_comment': ''},
#  183: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': '\n\nИньекция дексаметазона\n\n',
#   'analisys_cost': '0,96',
#   'analisys_comment': ''},
#  184: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': '\n\nШприц одноразовый\n\n',
#   'analisys_cost': '0,22',
#   'analisys_comment': ''},
#  185: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': '\n\nЩприц одноразовый 3мл трёхкомпонентный OMNIFIX LUER DUO с иглой 23G № 1\n\n',
#   'analisys_cost': '0,24',
#   'analisys_comment': ''},
#  186: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': '\n\nИгла PRE-300131-30G*13mm\n\n',
#   'analisys_cost': '1,76',
#   'analisys_comment': ''},
#  187: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': '\n\nИгла PRE-32004 *32G*4мм для подкожных инъекций ТСК\n\n',
#   'analisys_cost': '3,16',
#   'analisys_comment': ''},
#  188: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': '\n\nОтрез одноразовый 70*110\n\n',
#   'analisys_cost': '0,49',
#   'analisys_comment': ''},
#  189: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': '\n\nИмплантант вязкоэластичный REVOFIL AQASHINE BR\n\n',
#   'analisys_cost': '222,01',
#   'analisys_comment': ''},
#  190: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': '\n\nГель-крем "Lighfrosta\n\n',
#   'analisys_cost': '3,27',
#   'analisys_comment': ''},
#  191: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': '\n\nПостпилинговый защитный крем RDM-5\n\n',
#   'analisys_cost': '27,2',
#   'analisys_comment': ''},
#  192: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': '\n\nНабор пробирок REGENKIT -BCT-3\n\n',
#   'analisys_cost': '203,7',
#   'analisys_comment': ''},
#  193: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': '\n\nКОЛЛОСТ гель 7%\n\n',
#   'analisys_cost': '194,13',
#   'analisys_comment': ''},
#  194: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': '\n\nИмпланты гелевые на основе полинуклеатидов PLINEST\n\n',
#   'analisys_cost': '231',
#   'analisys_comment': ''},
#  195: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': '\n\nГель для внутридермального введения на основе полинуклеотидов и гиалуроновой кислоты NEWEST\n\n',
#   'analisys_cost': '243,44',
#   'analisys_comment': ''},
#  196: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': '\n\nКОЛЛОСТ гель 0.1 см3 проба\n\n',
#   'analisys_cost': '52,41',
#   'analisys_comment': ''},
#  197: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': '\n\nИмпланты REGENYAL IDEA\n\n',
#   'analisys_cost': '171,43',
#   'analisys_comment': ''},
#  198: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': '\n\nИМПЛАНТЫ REGENYAL SUPER IDEA\n\n',
#   'analisys_cost': '168,18',
#   'analisys_comment': ''},
#  199: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': '\n\nИМПЛАНТЫ REGENYAL BIOREGEN\n\n',
#   'analisys_cost': '88,15',
#   'analisys_comment': ''},
#  200: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Косметология',
#   'analisys_cost': '\xa0',
#   'analisys_comment': ''},
#  201: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Паровая ванночка',
#   'analisys_cost': '5,58',
#   'analisys_comment': ''},
#  202: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Гидрирующая маска',
#   'analisys_cost': '7,65',
#   'analisys_comment': ''},
#  203: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Противокуперозная маска для профилактики и лечения возрастной атрофии кожи лица',
#   'analisys_cost': '13,81',
#   'analisys_comment': ''},
#  204: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Маска для профилактики и лечения воспалительных заболеваний кожи лица',
#   'analisys_cost': '9,77',
#   'analisys_comment': ''},
#  205: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Массаж лица по Жаке',
#   'analisys_cost': '4,45',
#   'analisys_comment': ''},
#  206: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Очищение кожи лица механическое',
#   'analisys_cost': '11,86',
#   'analisys_comment': ''},
#  207: {'source': 'kvd.by',
#   'chapter': 'Косметологические услуги',
#   'analisys_name': 'Дарсонвализация лица',
#   'analisys_cost': '4,2',
#   'analisys_comment': ''},
#  208: {'source': 'kvd.by',
#   'chapter': 'Медицинский осмотр',
#   'analisys_name': 'Медицинский осмотр с выдачей заключения',
#   'analisys_cost': '4.42',
#   'analisys_comment': ''},
#  209: {'source': 'kvd.by',
#   'chapter': 'Медицинский осмотр',
#   'analisys_name': 'Анализ крови на сифилис методом ИФА',
#   'analisys_cost': '7.53',
#   'analisys_comment': ''},
#  210: {'source': 'kvd.by',
#   'chapter': 'Медицинский осмотр',
#   'analisys_name': 'Мазок на гонорею (мужчины)',
#   'analisys_cost': '7.91',
#   'analisys_comment': ''},
#  211: {'source': 'kvd.by',
#   'chapter': 'Медицинский осмотр',
#   'analisys_name': 'Мазок на гонорею (женщины)',
#   'analisys_cost': '13.55',
#   'analisys_comment': ''},
#  212: {'source': 'kvd.by',
#   'chapter': 'Медицинский осмотр',
#   'analisys_name': 'Медицинское обследование с выдачей заключения (мужчины)',
#   'analisys_cost': '28.22',
#   'analisys_comment': ''},
#  213: {'source': 'kvd.by',
#   'chapter': 'Медицинский осмотр',
#   'analisys_name': 'Медицинское обследование с выдачей заключения (женщины)',
#   'analisys_cost': '33.86',
#   'analisys_comment': ''},
#  214: {'source': 'kvd.by',
#   'chapter': 'Консультации врачей-специалистов',
#   'analisys_name': 'Консультация врача высшей категории',
#   'analisys_cost': '19,26',
#   'analisys_comment': ''},
#  215: {'source': 'kvd.by',
#   'chapter': 'Консультации врачей-специалистов',
#   'analisys_name': 'Консультация врача первой категории',
#   'analisys_cost': '18,61',
#   'analisys_comment': ''},
#  216: {'source': 'kvd.by',
#   'chapter': 'Консультации врачей-специалистов',
#   'analisys_name': 'Консультация врача второй категории',
# ...
#   'analisys_name': 'Определение глюкозы в сыворотке крови',
#   'analisys_cost': '3,00',
#   'analisys_comment': ''},
#  249: {'source': 'kvd.by',
#   'chapter': 'Исследования клинико-диагностической лаборатории ',
#   'analisys_name': 'Исследование состояния гемостаза без забора крови',
#   'analisys_cost': '34,89',
#   'analisys_comment': ''},
#  250: {'source': 'kvd.by',
#   'chapter': 'Исследования клинико-диагностической лаборатории ',
#   'analisys_name': 'Определение содержания фибриногена в плазме крови без забора крови',
#   'analisys_cost': '9,29',
#   'analisys_comment': ''},
#  251: {'source': 'kvd.by',
#   'chapter': 'Исследования клинико-диагностической лаборатории ',
#   'analisys_name': 'Микроскопическое исследование отделяемого мочеполовых органов, окрашенных метиленовым синим',
#   'analisys_cost': '3,28',
#   'analisys_comment': ''},
#  252: {'source': 'kvd.by',
#   'chapter': 'Исследования клинико-диагностической лаборатории ',
#   'analisys_name': 'Микроскопическое исследование отделяемого мочеполовых органов, окрашенных по Грамму',
#   'analisys_cost': '4,23',
#   'analisys_comment': ''},
#  253: {'source': 'kvd.by',
#   'chapter': 'Исследования клинико-диагностической лаборатории ',
#   'analisys_name': 'БИОХИМИЧЕСКИЙ АНАЛИЗ КРОВИ - Общий белок',
#   'analisys_cost': '0,80',
#   'analisys_comment': ''},
#  254: {'source': 'kvd.by',
#   'chapter': 'Исследования клинико-диагностической лаборатории ',
#   'analisys_name': 'Мочевина',
#   'analisys_cost': '0,33',
#   'analisys_comment': ''},
#  255: {'source': 'kvd.by',
#   'chapter': 'Исследования клинико-диагностической лаборатории ',
#   'analisys_name': 'Общий холестерин',
#   'analisys_cost': '0,29',
#   'analisys_comment': ''},
#  256: {'source': 'kvd.by',
#   'chapter': 'Исследования клинико-диагностической лаборатории ',
#   'analisys_name': 'Креатинин',
#   'analisys_cost': '0,28',
#   'analisys_comment': ''},
#  257: {'source': 'kvd.by',
#   'chapter': 'Исследования клинико-диагностической лаборатории ',
#   'analisys_name': 'Мочевая кислота',
#   'analisys_cost': '0,33',
#   'analisys_comment': ''},
#  258: {'source': 'kvd.by',
#   'chapter': 'Исследования клинико-диагностической лаборатории ',
#   'analisys_name': 'Общий билирубин',
#   'analisys_cost': '0,33',
#   'analisys_comment': ''},
#  259: {'source': 'kvd.by',
#   'chapter': 'Исследования клинико-диагностической лаборатории ',
#   'analisys_name': 'Прямой билирубин',
#   'analisys_cost': '0,31',
#   'analisys_comment': ''},
#  260: {'source': 'kvd.by',
#   'chapter': 'Исследования клинико-диагностической лаборатории ',
#   'analisys_name': 'Триглицириды',
#   'analisys_cost': '0,36',
#   'analisys_comment': ''},
#  261: {'source': 'kvd.by',
#   'chapter': 'Исследования клинико-диагностической лаборатории ',
#   'analisys_name': 'АСТ',
#   'analisys_cost': '0,31',
#   'analisys_comment': ''},
#  262: {'source': 'kvd.by',
#   'chapter': 'Исследования клинико-диагностической лаборатории ',
#   'analisys_name': 'АЛТ',
#   'analisys_cost': '0,31',
#   'analisys_comment': ''},
#  263: {'source': 'kvd.by',
#   'chapter': 'Исследования клинико-диагностической лаборатории ',
#   'analisys_name': 'Глюкоза',
#   'analisys_cost': '0,28',
#   'analisys_comment': ''},
#  264: {'source': 'kvd.by',
#   'chapter': 'Исследования клинико-диагностической лаборатории ',
#   'analisys_name': 'Криатинкиназа',
#   'analisys_cost': '0,53',
#   'analisys_comment': ''},
#  265: {'source': 'kvd.by',
#   'chapter': 'Исследования клинико-диагностической лаборатории ',
#   'analisys_name': 'ЛДГ',
#   'analisys_cost': '0,32',
#   'analisys_comment': ''},
#  266: {'source': 'kvd.by',
#   'chapter': 'Исследования клинико-диагностической лаборатории ',
#   'analisys_name': 'Щелочная фосфатаза',
#   'analisys_cost': '0,29',
#   'analisys_comment': ''},
#  267: {'source': 'kvd.by',
#   'chapter': 'Исследования клинико-диагностической лаборатории ',
#   'analisys_name': 'ГГТП',
#   'analisys_cost': '0,40',
#   'analisys_comment': ''},
#  268: {'source': 'kvd.by',
#   'chapter': 'Исследования клинико-диагностической лаборатории ',
#   'analisys_name': 'Кальций',
#   'analisys_cost': '0,29',
#   'analisys_comment': ''},
#  269: {'source': 'kvd.by',
#   'chapter': 'Исследования клинико-диагностической лаборатории ',
#   'analisys_name': 'Магний',
#   'analisys_cost': '0,30',
#   'analisys_comment': ''},
#  270: {'source': 'kvd.by',
#   'chapter': 'Исследования клинико-диагностической лаборатории ',
#   'analisys_name': 'Фосфор',
#   'analisys_cost': '0,31',
#   'analisys_comment': ''},
#  271: {'source': 'kvd.by',
#   'chapter': 'Исследования клинико-диагностической лаборатории ',
#   'analisys_name': 'Амилаза',
#   'analisys_cost': '0,65',
#   'analisys_comment': ''},
#  272: {'source': 'kvd.by',
#   'chapter': 'Исследования клинико-диагностической лаборатории ',
#   'analisys_name': 'Железо',
#   'analisys_cost': '0,34',
#   'analisys_comment': ''},
#  273: {'source': 'kvd.by',
#   'chapter': 'Исследования клинико-диагностической лаборатории ',
#   'analisys_name': 'Альбумин',
#   'analisys_cost': '0,29',
#   'analisys_comment': ''},
#  274: {'source': 'kvd.by',
#   'chapter': 'Исследования клинико-диагностической лаборатории ',
#   'analisys_name': 'Креатинкиназа-МБ',
#   'analisys_cost': '1,15',
#   'analisys_comment': ''},
#  275: {'source': 'kvd.by',
#   'chapter': 'Исследования клинико-диагностической лаборатории ',
#   'analisys_name': 'Холестирин -ЛПВП',
#   'analisys_cost': '1,54',
#   'analisys_comment': ''},
#  276: {'source': 'kvd.by',
#   'chapter': 'Исследования клинико-диагностической лаборатории ',
#   'analisys_name': 'АСЛ',
#   'analisys_cost': '3,94',
#   'analisys_comment': ''},
#  277: {'source': 'kvd.by',
#   'chapter': 'Исследования клинико-диагностической лаборатории ',
#   'analisys_name': 'РФ',
#   'analisys_cost': '3,92',
#   'analisys_comment': ''},
#  278: {'source': 'kvd.by',
#   'chapter': 'Исследования клинико-диагностической лаборатории ',
#   'analisys_name': 'СРБ',
#   'analisys_cost': '3,93',
#   'analisys_comment': ''},
#  279: {'source': 'kvd.by',
#   'chapter': 'Исследования клинико-диагностической лаборатории ',
#   'analisys_name': '\n\nРеагенты дианостические для биохимического исследования крови\n\n',
#   'analisys_cost': '0,80',
#   'analisys_comment': ''},
#  280: {'source': 'kvd.by',
#   'chapter': 'Исследования клинико-диагностической лаборатории ',
#   'analisys_name': '\n\nРасходные материалы\n\n',
#   'analisys_cost': '1,68',
#   'analisys_comment': ''},
#  281: {'source': 'kvd.by',
#   'chapter': 'Исследования клинико-диагностической лаборатории ',
#   'analisys_name': 'Исследования эякулята человека',
#   'analisys_cost': '17,24',
#   'analisys_comment': ''},
#  282: {'source': 'kvd.by',
#   'chapter': 'Исследования клинико-диагностической лаборатории ',
#   'analisys_name': 'Прием и регистрация проб',
#   'analisys_cost': '0,62',
#   'analisys_comment': ''},
#  283: {'source': 'kvd.by',
#   'chapter': 'Гормональные исследования (анализ крови на гормоны)',
#   'analisys_name': 'гормоны без забора',
#   'analisys_cost': '\xa0',
#   'analisys_comment': ''},
#  284: {'source': 'kvd.by',
#   'chapter': 'Гормональные исследования (анализ крови на гормоны)',
#   'analisys_name': 'Обработка венозной крови для получения сыворотки с приемом и регистрацией\xa0 проб(п.1.5.1+1,2)',
#   'analisys_cost': '1,24',
#   'analisys_comment': ''},
#  285: {'source': 'kvd.by',
#   'chapter': 'Гормональные исследования (анализ крови на гормоны)',
#   'analisys_name': 'Иммуноферментный анализ крови на половые гормоны (пролактин,\xa0 тестестерон, прогестерон, эстрадиол ,ФСГ, ЛГ, кортизол) с пипетирование и регистрацией согласно протоколу',
#   'analisys_cost': '55,86',
#   'analisys_comment': ''},
#  286: {'source': 'kvd.by',
#   'chapter': 'РРЛ по диагностике сифилиса',
#   'analisys_name': '\xa0',
#   'analisys_cost': '\xa0',
#   'analisys_comment': ''},
#  287: {'source': 'kvd.by',
#   'chapter': 'РРЛ по диагностике сифилиса',
#   'analisys_name': 'Определение иммуноглобулинов к бледной трепонеме методом ИФА',
#   'analisys_cost': '5,19',
#   'analisys_comment': ''},
#  288: {'source': 'kvd.by',
#   'chapter': 'РРЛ по диагностике сифилиса',
#   'analisys_name': 'Комплекс ИФА+RPR',
#   'analisys_cost': '12,41',
#   'analisys_comment': ''},
#  289: {'source': 'kvd.by',
#   'chapter': 'РРЛ по диагностике сифилиса',
#   'analisys_name': 'Реакция быстрых плазменных реагинов ( RPR) качественный метод',
#   'analisys_cost': '8,36',
#   'analisys_comment': ''},
#  290: {'source': 'kvd.by',
#   'chapter': 'РРЛ по диагностике сифилиса',
#   'analisys_name': 'Реакция быстрых плазменных реагинов (RPR) количественный метод',
#   'analisys_cost': '8,31',
#   'analisys_comment': ''},
#  291: {'source': 'kvd.by',
#   'chapter': 'РРЛ по диагностике сифилиса',
#   'analisys_name': 'Реакция пассивной гемагглютинации (РПГА) качественный метод',
#   'analisys_cost': '10,68',
#   'analisys_comment': ''},
#  292: {'source': 'kvd.by',
#   'chapter': 'РРЛ по диагностике сифилиса',
#   'analisys_name': 'Реакция пассивной гемагглютинации( РПГА) количественным методом',
#   'analisys_cost': '25,32',
#   'analisys_comment': ''},
#  293: {'source': 'kvd.by',
#   'chapter': 'РРЛ по диагностике сифилиса',
#   'analisys_name': 'Реакция иммунофлуоресценции (РИФ)качественный метод (с нефиксированным на стекле антигеном)',
#   'analisys_cost': '22,4',
#   'analisys_comment': ''},
#  294: {'source': 'kvd.by',
#   'chapter': 'РРЛ по диагностике сифилиса',
#   'analisys_name': 'Реакция иммунофлуоресценции (РИФ) количественный метод (с нефиксированным на стекле антигеном)',
#   'analisys_cost': '47,86',
#   'analisys_comment': ''},
#  295: {'source': 'kvd.by',
#   'chapter': 'РРЛ по диагностике сифилиса',
#   'analisys_name': 'Антитела к спайковому (S)белку SARS-Cov-2) Ig G (полуколичественное определение ). Оценка постинфекционного .поствакционного иммунитета.',
#   'analisys_cost': '3,85',
#   'analisys_comment': ''},
#  296: {'source': 'kvd.by',
#   'chapter': 'РРЛ по диагностике сифилиса',
#   'analisys_name': 'Определение общей концентрации 25-ОН витамина Д методом ИФА',
#   'analisys_cost': '32,48',
#   'analisys_comment': ''},
#  297: {'source': 'kvd.by',
#   'chapter': 'РРЛ по диагностике сифилиса',
#   'analisys_name': 'методом ИФА Лямблия полуавтоматизированный анализ',
#   'analisys_cost': '17,21',
#   'analisys_comment': ''},
#  298: {'source': 'kvd.by',
#   'chapter': 'РРЛ по диагностике сифилиса',
#   'analisys_name': 'методом ИФА Гельминты полуавтоматизированный анализ',
#   'analisys_cost': '34,81',
#   'analisys_comment': ''},
#  299: {'source': 'kvd.by',
#   'chapter': 'РРЛ по диагностике сифилиса',
#   'analisys_name': 'методом ИФА Хеликобактер пилори полуавтоматизированный анализ',
#   'analisys_cost': '8,22',
#   'analisys_comment': ''},
#  300: {'source': 'kvd.by',
#   'chapter': 'РРЛ по диагностике сифилиса',
#   'analisys_name': 'методом ИФА Аскарида полуавтоматизированный анализ',
#   'analisys_cost': '9,12',
#   'analisys_comment': ''},
#  301: {'source': 'kvd.by',
#   'chapter': 'РРЛ по диагностике сифилиса',
#   'analisys_name': 'методом ИФА гормоны щитовидной железы ТТГ полуавтоматизированный анализ',
#   'analisys_cost': '7,11',
#   'analisys_comment': ''},
#  302: {'source': 'kvd.by',
#   'chapter': 'РРЛ по диагностике сифилиса',
#   'analisys_name': 'методом ИФА гормоны щитовидной железы Свободный Т- 4 полуавтоматизированный анализ',
#   'analisys_cost': '7,64',
#   'analisys_comment': ''},
#  303: {'source': 'kvd.by',
#   'chapter': 'РРЛ по диагностике сифилиса',
#   'analisys_name': 'методом ИФА гормоны щитовидной железы Анти-ТПО) полуавтоматизированный анализ',
#   'analisys_cost': '8,27',
#   'analisys_comment': ''},
#  304: {'source': 'kvd.by',
#   'chapter': 'Исследования бактериологической лаборатории',
#   'analisys_name': 'Культуральное исследование на аэробные и факультативно-анаэробные микроорганизмы в гное с идентификацией микроорганизмов до вида классическим методом с взятием материама',
#   'analisys_cost': '36,16',
#   'analisys_comment': ''},
#  305: {'source': 'kvd.by',
#   'chapter': 'Исследования бактериологической лаборатории',
#   'analisys_name': 'Культуральное исследование на аэробные и факультативно-анаэробные микроорганизмы в гное с идентификацией микроорганизмов до вида на автоматическом микробиологическом анализаторе с взятием материала.',
#   'analisys_cost': '88,54',
#   'analisys_comment': ''},
#  306: {'source': 'kvd.by',
#   'chapter': 'Исследования бактериологической лаборатории',
#   'analisys_name': 'Культуральное исследование на аэробные и факультативно-анаэробные микроорганизмы в\xa0 отделяемом урогенитального тракта с идентификацией микроорганизмов до вида классическим методом',
#   'analisys_cost': '38,24',
#   'analisys_comment': ''},
#  307: {'source': 'kvd.by',
#   'chapter': 'Исследования бактериологической лаборатории',
#   'analisys_name': 'Культуральное исследование на аэробные и факультативно-анаэробные микроорганизмы в отделяемом урогенитального тракта\xa0 с идентификацией микроорганизмов до вида на автоматическом микробиологическом анализаторе.',
#   'analisys_cost': '90,43',
#   'analisys_comment': ''},
#  308: {'source': 'kvd.by',
#   'chapter': 'Исследования бактериологической лаборатории',
#   'analisys_name': 'Культуральное исследование на аэробные и факультативно-анаэробные микроорганизмы в отделяемом носоглотки, носа, зева с идентификацией микроорганизмов до вида классическим методом с взятием материала',
#   'analisys_cost': '38,5',
#   'analisys_comment': ''},
#  309: {'source': 'kvd.by',
#   'chapter': 'Исследования бактериологической лаборатории',
#   'analisys_name': 'Культуральное исследование на аэробные и факультативно-анаэробные микроорганизмы в\xa0 носоглотки, носа, зева с идентификацией микроорганизмов до вида на автоматическом микробиологическом анализаторе с взятием материала.',
#   'analisys_cost': '91,65',
#   'analisys_comment': ''},
#  310: {'source': 'kvd.by',
#   'chapter': 'Исследования бактериологической лаборатории',
#   'analisys_name': 'Культуральное исследование отделяемого мочеполовых органов на гонококковую инфекцию',
#   'analisys_cost': '17,51',
#   'analisys_comment': ''},
#  311: {'source': 'kvd.by',
#   'chapter': 'Исследования бактериологической лаборатории',
#   'analisys_name': 'Культуральное исследование мочеполовых органов на гонококковую инфекцию с идентификацией до вида классическим методом',
#   'analisys_cost': '36,38',
#   'analisys_comment': ''},
#  312: {'source': 'kvd.by',
#   'chapter': 'Исследования бактериологической лаборатории',
#   'analisys_name': 'Исследование на уреа-микоплазмы в отделяемом мочеполовых органов с использованием коммерческих тест- систем без забора материала в лаборатории.',
#   'analisys_cost': '23,54',
#   'analisys_comment': ''},
#  313: {'source': 'kvd.by',
#   'chapter': 'Исследования бактериологической лаборатории',
#   'analisys_name': 'Микроскопическое исследование кожи и слизистых ногтей волос на дерматофиты и дрожжеподобные грибы с забором материала в лаборатории',
#   'analisys_cost': '2,29',
#   'analisys_comment': ''},
#  314: {'source': 'kvd.by',
#   'chapter': 'Исследования бактериологической лаборатории',
#   'analisys_name': 'Культуральное исследование кожи и слизистых, ногтей, волос на дерматофиты и дрожжеподобные грибы с забором материала в лаборатории',
#   'analisys_cost': '6,77',
#   'analisys_comment': ''},
#  315: {'source': 'kvd.by',
#   'chapter': 'Исследования бактериологической лаборатории',
#   'analisys_name': 'Культуральное исследование\xa0 слизистых на дрожжеподобные грибы (рода (Candida)\xa0 с забором материала в лаборатории',
#   'analisys_cost': '11,12',
#   'analisys_comment': ''},
#  316: {'source': 'kvd.by',
#   'chapter': 'Исследования бактериологической лаборатории',
#   'analisys_name': 'Обнаружение чесоточного клеща в исследуемом материале с забором\xa0 материала в лаборатории',
#   'analisys_cost': '3,04',
#   'analisys_comment': ''},
#  317: {'source': 'kvd.by',
#   'chapter': 'Исследования бактериологической лаборатории',
#   'analisys_name': 'Обнаружение Demodex foliorum hominis в исследуемом материале с забором\xa0 материала в лаборатории',
#   'analisys_cost': '3,04',
#   'analisys_comment': ''},
#  318: {'source': 'kvd.by',
#   'chapter': 'Дерматоскопия',
#   'analisys_name': '\nДерматоскопия\n',
#   'analisys_cost': '\n29,16\n',
#   'analisys_comment': ''},
#  319: {'source': 'kvd.by',
#   'chapter': 'Дерматоскопия',
#   'analisys_name': '\nДерматоскопия (каждая посл.)\n',
#   'analisys_cost': '\n14,26\n',
#   'analisys_comment': ''}}

# %%
df_kvd = pd.DataFrame.from_dict(dict_kvd.values())
with pd.option_context('display.max_colwidth', None):
    print(df_kvd.analisys_name.head(30))
# Out:
# 0                                                                                     АППАРАТНОЕ УДАЛЕНИЕ НОГТЕЙ
# 1                             Аппаратное удаление пораженной ногтевой пластинки большого пальца стопы или кисти.
# 2                                       Аппаратное удаление одной пораженной ногтевой пластинки стопы или кисти.
# 3                Механическое удаление пораженных частей ногтевой пластинки пальца стопы (кисти)при онихомикозе.
# 4                                                                                         Комплект на 1 человека
# 5                                          Одноразовый комплект для пациента (по желанию пациента дополнительно)
# 6                                                                                       Прием и регистрация проб
# 7                                           Приём, регистрация и сортировка проб в централизованных лабораториях
# 8                                         Взятие биологического материала с помощью транспортных сред и тампонов
# 9                                                                   Первичная обработка биологического материала
# 10                                                                  Первичная обработка биологического материала
# 11                                             Первичная обработка биологического материала (транспортная среда)
# 12                              Выделение ДНК из иного биологического материала ручным способом сорбентный метод
# 13    Выделение ДНК из иного биологическогоматериала ручным способом сорбентный метод (Реал-Бест ДНК-экстракция)
# 14                                     Выделение РНК из иного биологического материала (назофарингеальные мазки)
# 15                                          Выявления Сhlamydia trachomatis методом ПЦР качественное определение
# 16                               Выявления HSV I,II -вирус простого герпеса методом ПЦР качественное определение
# 17                                 Выявления HPV - вирус папилломы человека методом ПЦР качественное определение
# 18                                          Выявления Тrichomonas vaginalis методом ПЦР качественное определение
# 19                                          Выявления Mycoplasma genitalium методом ПЦР качественное определение
# 20                                          Выявления Neisseria gonorrhoeae методом ПЦР качественное определение
# 21                                         Выявления Ureaplasma urealyticum методом ПЦР качественное определение
# 22                        Выявление инфекционных возбудителей "ФЕМОФЛОР-СКРИН" (1.2 +9.1.2. +9.3.1.2.4 +9.4.2.1)
# 23                               Выявления HPV - вирус папилломы человека методом ПЦР КОЛИЧЕСТВЕННОЕ определение
# 24                                                                   Выявление РНК инфекции COVID-19 методом ПЦР
# 25                              Тестирование с QR-кодом через информационную систему " Путешествую без COVID-19"
# 26                                                                     Оформление документов для выезда за рубеж
# 27                                                                     Взятие материала для исследования биопсии
# 28                             Гистологическое исследование операционногого, биопсийного и секционного материала
# 29                                                          Консультация готовых гистологических микропрепаратов
# Name: analisys_name, dtype: object

# %%
dSynlab = DriverSynlab()

# %%
dSynlab.scan()

# %%
lst = dSynlab.get_analisys()

# %%
df_synlab = pd.DataFrame.from_dict(lst.values())
df_synlab[100:200]
# Out:
#         source                     chapter  \
# 100  Synlab.by  БИОХИМИЧЕСКИЕ ИССЛЕДОВАНИЯ
# 101  Synlab.by  БИОХИМИЧЕСКИЕ ИССЛЕДОВАНИЯ
# 102  Synlab.by  БИОХИМИЧЕСКИЕ ИССЛЕДОВАНИЯ
# 103  Synlab.by  БИОХИМИЧЕСКИЕ ИССЛЕДОВАНИЯ
# 104  Synlab.by  БИОХИМИЧЕСКИЕ ИССЛЕДОВАНИЯ
# ..         ...                         ...
# 195  Synlab.by   ГОРМОНАЛЬНЫЕ ИССЛЕДОВАНИЯ
# 196  Synlab.by   ГОРМОНАЛЬНЫЕ ИССЛЕДОВАНИЯ
# 197  Synlab.by   ГОРМОНАЛЬНЫЕ ИССЛЕДОВАНИЯ
# 198  Synlab.by   ГОРМОНАЛЬНЫЕ ИССЛЕДОВАНИЯ
# 199  Synlab.by   ГОРМОНАЛЬНЫЕ ИССЛЕДОВАНИЯ
#
#                               analisys_name analisys_cost  \
# 100                   ЛПВП-холестерин (HDL)          2,69
# 101                   ЛПНП-холестерин (LDL)          2,50
# 102                           Липопротеин А         27.67
# 103              Аполипопротеин А1 (APO-A1)          6.40
# 104                Аполипопротеин B (APO-B)          5.54
# ..                                      ...           ...
# 195  Anti-TPO (Антитела к тиреопероксидазе)        15. 64
# 196  Anti-TSHR (Антитела к рецепторам TSH )         34.54
# 197                             Кальцитонин         55.54
# 198                             Паратгормон         22.19
# 199     Human Growth Hormone (Гормон роста)         34.07
#
#                                   analisys_comment
# 100                                  Жировой обмен
# 101                                  Жировой обмен
# 102                                  Жировой обмен
# 103                                  Жировой обмен
# 104                                  Жировой обмен
# ..                                             ...
# 195  Лабораторная оценка функции щитовидной железы
# 196  Лабораторная оценка функции щитовидной железы
# 197  Лабораторная оценка функции щитовидной железы
# 198  Лабораторная оценка функции щитовидной железы
# 199                      Лабораторная оценка роста
#
# [100 rows x 5 columns]

# %%
df = pd.concat([df_kvd, df_maka, df_synlab])
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df = pd.concat([df_kvd, df_maka, df_synlab])
#       2 df
#
# NameError: name 'df_kvd' is not defined

# %%
mask = df['analisys_name'].str.contains('D') | df['analisys_name'].str.contains('АЛТ')
filtered_df = df[mask]
filtered_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 mask = df['analisys_name'].str.contains('D') | df['analisys_name'].str.contains('АЛТ')
#       2 filtered_df = df[mask]
#       3 filtered_df
#
# NameError: name 'df' is not defined
