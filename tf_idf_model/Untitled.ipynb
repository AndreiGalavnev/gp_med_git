# %%
#from re import A
import pandas as pd
import numpy as np
#import nltk
from nltk import RegexpTokenizer
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from nltk.corpus import PlaintextCorpusReader
#import sys
import streamlit as st

#nltk.data.path.append('stopwords')



# Загрузка стоп-слов для определенного языка из файловой системы
#corpus_root = 'C:/Users/user/PycharmProjects/local_gp_med/gp_med/stopwords'
#stopwords = PlaintextCorpusReader(corpus_root, '.*')

#file_pattern = r'russian\.txt'  # Шаблон имени файла, например, russian.txt

#corpus = PlaintextCorpusReader(corpus_root, file_pattern)

#stopwords = corpus.words('russian.txt')

#stop_words = set(stopwords)
stop_words = set(stopwords.words('russian'))
custom_stop_words = ("анализ", "уровень", "определение", "анализы", "консультация", "выявление")
a = (set(stop_words.union(custom_stop_words)))
print(a)
print(type(a))
# Out:
# {'мы', 'только', 'тем', 'были', 'было', 'много', 'вы', 'кто', 'три', 'будет', 'бы', 'выявление', 'же', 'можно', 'где', 'чего', 'но', 'здесь', 'им', 'определение', 'после', 'даже', 'под', 'эту', 'ж', 'а', 'ну', 'себе', 'вот', 'не', 'моя', 'что', 'ней', 'нее', 'эти', 'от', 'как', 'тогда', 'чтоб', 'со', 'в', 'зачем', 'больше', 'тот', 'нельзя', 'анализы', 'была', 'иногда', 'лучше', 'она', 'чтобы', 'нибудь', 'хорошо', 'есть', 'того', 'какая', 'них', 'мне', 'всю', 'меня', 'анализ', 'быть', 'уж', 'себя', 'через', 'опять', 'ее', 'вам', 'мой', 'этого', 'с', 'раз', 'вдруг', 'тоже', 'этот', 'сейчас', 'свою', 'два', 'этой', 'наконец', 'то', 'без', 'ли', 'ему', 'теперь', 'уже', 'уровень', 'нет', 'когда', 'на', 'тут', 'перед', 'впрочем', 'они', 'может', 'будто', 'чем', 'разве', 'если', 'какой', 'там', 'ты', 'из', 'всех', 'да', 'его', 'их', 'другой', 'потому', 'об', 'нас', 'за', 'по', 'до', 'ничего', 'всегда', 'ей', 'над', 'и', 'него', 'так', 'между', 'консультация', 'все', 'он', 'сам', 'куда', 'про', 'еще', 'ведь', 'ним', 'вас', 'почти', 'конечно', 'этом', 'при', 'ни', 'том', 'надо', 'хоть', 'такой', 'никогда', 'я', 'для', 'более', 'был', 'один', 'у', 'совсем', 'чуть', 'потом', 'к', 'во', 'всего', 'тебя', 'или', 'о'}
# <class 'set'>

# %%
#from re import A
import pandas as pd
import numpy as np
#import nltk
from nltk import RegexpTokenizer
#from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from nltk.corpus import PlaintextCorpusReader
#import sys
import streamlit as st

#nltk.data.path.append('stopwords')



# Загрузка стоп-слов для определенного языка из файловой системы
corpus_root = 'C:/Users/user/PycharmProjects/local_gp_med/gp_med/stopwords'
#stopwords = PlaintextCorpusReader(corpus_root, '.*')

file_pattern = r'russian\.txt'  # Шаблон имени файла, например, russian.txt

corpus = PlaintextCorpusReader(corpus_root, file_pattern)

stopwords = corpus.words('russian.txt')

stop_words = set(stopwords)
#stop_words = set(stopwords.words('russian'))
custom_stop_words = ("анализ", "уровень", "определение", "анализы", "консультация", "выявление")
b = set(stop_words.union(custom_stop_words))
print(b)
print(type(b))
# Out:
# {'определение', 'как', 'конечно', 'свою', 'над', 'этого', 'мой', 'моя', 'было', 'ли', 'через', 'более', 'теперь', 'тот', 'иногда', 'хоть', 'один', 'где', 'со', 'была', 'вам', 'здесь', 'два', 'а', 'и', 'тогда', 'тебя', 'можно', 'хорошо', 'ним', 'сам', 'почти', 'всю', 'консультация', 'под', 'себя', 'зачем', 'еще', 'с', 'опять', 'будет', 'них', 'раз', 'ведь', 'тут', 'во', 'нас', 'ты', 'какой', 'выявление', 'потому', 'когда', 'нет', 'они', 'по', 'из', 'анализы', 'я', 'меня', 'может', 'эти', 'никогда', 'вы', 'лучше', 'нельзя', 'совсем', 'нее', 'об', 'же', 'перед', 'всех', 'ему', 'от', 'но', 'всегда', 'что', 'даже', 'том', 'ей', 'вдруг', 'ничего', 'этот', 'если', 'у', 'разве', 'чем', 'этой', 'после', 'без', 'до', 'какая', 'ну', 'нибудь', 'не', 'между', 'только', 'им', 'ж', 'в', 'то', 'к', 'ней', 'куда', 'мы', 'вас', 'тем', 'уже', 'бы', 'чтоб', 'чуть', 'он', 'эту', 'при', 'она', 'наконец', 'себе', 'всего', 'про', 'того', 'за', 'сейчас', 'тоже', 'другой', 'много', 'будто', 'такой', 'уровень', 'вот', 'все', 'или', 'есть', 'кто', 'так', 'потом', 'больше', 'уж', 'их', 'быть', 'впрочем', 'для', 'него', 'три', 'его', 'был', 'мне', 'чтобы', 'ее', 'надо', 'были', 'о', 'этом', 'ни', 'анализ', 'на', 'чего', 'да', 'там'}
# <class 'set'>

# %%
print(b)
print(type(b))
# Out:
# {'того', 'есть', 'такой', 'ей', 'по', 'хорошо', 'еще', 'меня', 'под', 'чем', 'чуть', 'зачем', 'эти', 'всех', 'бы', 'куда', 'или', 'уровень', 'об', 'их', 'него', 'ж', 'можно', 'другой', 'без', 'может', 'выявление', 'нас', 'даже', 'какой', 'ни', 'один', 'хоть', 'потом', 'над', 'через', 'к', 'он', 'она', 'если', 'будто', 'будет', 'тоже', 'там', 'себя', 'какая', 'ничего', 'чтоб', 'был', 'эту', 'была', 'консультация', 'я', 'опять', 'его', 'вы', 'только', 'наконец', 'анализы', 'что', 'нельзя', 'почти', 'тот', 'ней', 'были', 'этом', 'но', 'более', 'они', 'тогда', 'кто', 'конечно', 'из', 'же', 'после', 'в', 'три', 'всего', 'ее', 'иногда', 'сейчас', 'то', 'о', 'всегда', 'себе', 'уж', 'тут', 'во', 'нет', 'этой', 'как', 'нее', 'а', 'много', 'всю', 'ним', 'от', 'теперь', 'между', 'да', 'у', 'так', 'мне', 'со', 'уже', 'вас', 'сам', 'больше', 'свою', 'раз', 'лучше', 'тем', 'вот', 'для', 'ну', 'здесь', 'два', 'быть', 'чтобы', 'где', 'перед', 'никогда', 'надо', 'вам', 'них', 'этого', 'мы', 'с', 'чего', 'определение', 'при', 'до', 'про', 'когда', 'было', 'ты', 'потому', 'нибудь', 'совсем', 'на', 'вдруг', 'этот', 'том', 'все', 'разве', 'мой', 'впрочем', 'им', 'ведь', 'моя', 'анализ', 'за', 'и', 'не', 'ли', 'ему', 'тебя'}

# %%
print(a)
print(type(a))
# Out:
# {'больше', 'что', 'он', 'тот', 'и', 'какая', 'этого', 'другой', 'для', 'хоть', 'ним', 'есть', 'будто', 'вам', 'ты', 'ведь', 'тогда', 'кто', 'чуть', 'определение', 'него', 'ее', 'чего', 'если', 'с', 'были', 'себя', 'этой', 'может', 'анализ', 'по', 'они', 'без', 'ней', 'меня', 'все', 'куда', 'когда', 'чем', 'при', 'нет', 'тут', 'эту', 'них', 'совсем', 'после', 'том', 'было', 'над', 'наконец', 'их', 'вас', 'уровень', 'моя', 'того', 'от', 'она', 'выявление', 'до', 'вот', 'через', 'такой', 'всегда', 'два', 'можно', 'у', 'этот', 'какой', 'еще', 'эти', 'нас', 'чтоб', 'зачем', 'нибудь', 'об', 'ли', 'тем', 'тоже', 'нее', 'вдруг', 'быть', 'иногда', 'чтобы', 'со', 'но', 'ни', 'тебя', 'нельзя', 'во', 'сам', 'всю', 'свою', 'себе', 'из', 'впрочем', 'потому', 'перед', 'никогда', 'о', 'между', 'разве', 'три', 'его', 'опять', 'здесь', 'мы', 'ничего', 'этом', 'более', 'так', 'всего', 'ей', 'надо', 'ну', 'да', 'мой', 'даже', 'почти', 'была', 'много', 'ж', 'а', 'уже', 'конечно', 'ему', 'мне', 'вы', 'консультация', 'к', 'под', 'сейчас', 'на', 'за', 'только', 'где', 'анализы', 'или', 'там', 'про', 'же', 'им', 'один', 'лучше', 'как', 'был', 'то', 'не', 'теперь', 'уж', 'в', 'раз', 'всех', 'хорошо', 'будет', 'бы', 'потом', 'я'}
# <class 'set'>
